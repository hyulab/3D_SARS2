# %%
# Set the process name to be human readable in htop
import setproctitle
setproctitle.setproctitle("Guided_Docking_Test")

import helper as my
import pandas as pd
pd.options.display.max_columns = 999
import numpy as np

import os
os.environ["TMPDIR"] = "/tmp"
import glob

from tqdm import tqdm, tqdm_notebook
from tqdm._tqdm_notebook import tqdm_notebook

tqdm.pandas(tqdm_notebook)
tqdm_notebook.pandas()

# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt

from collections import defaultdict

import scipy

# %%
from mjm_tools import unzip_res_range, zip_res_range

# %% [markdown]
# # Initial Test Using Known Structures

# %%
# Read in Info for Ires / Sifts Mapping

# %%
ires = pd.read_csv("[REDACTED_PATH]/ires/parsed_files/ires_perpdb_alltax.txt", sep="\t")

# %%
sifts = pd.read_csv("[REDACTED_PATH]/sifts/parsed_files/pdbresiduemapping.txt", sep="\t")

# %%
pos_maps = sifts.set_index(["PDB", "Chain", "UniProt"])[["MappableResInPDBChainOnUniprotBasis", "MappableResInPDBChainOnPDBBasis"]].apply(lambda x: dict(zip(unzip_res_range(x[1]), unzip_res_range(x[0]))), axis=1).to_dict()

# %%
# Get access to ECLAIR Predictions
host = "[REDACTED]"
db = "eclair"
user, pw = my.retrieve("MYSQL")
mydb = my.MySQLdb.connect(host=host, user=user, passwd=pw, db=db)

# %%
# Select random interfaces from exisint heteromeric PDB chain pairs
selections = []
tmp = ires[(ires["UniProtA"] != ires["UniProtB"])&(ires["TaxIDA"] == 9606.0)&(ires["TaxIDB"] == 9606.0)]
tmp = tmp.sample(len(tmp))
for uniA, uniB, pdb, chainA, chainB, iresA, iresB, in tqdm_notebook(tmp[["UniProtA", "UniProtB", "PDB", "ChainA", "ChainB", "UniProtIresA", "UniProtIresB"]].values):
    if(len(pd.read_sql_query("select * from eclair_predictions where P1 = '{0}' and P2 = '{1}'".format(*sorted([uniA, uniB])), mydb)) > 0):
        selections.append([uniA, uniB, pdb, chainA, chainB, iresA, iresB])
    if(len(selections) >= 50):
        break
# Out:
# HBox(children=(IntProgress(value=0, max=9295), HTML(value=u'')))

# %%
len(selections)
# Out:
# 50

# %%
# Reindex structures so they are numbered by Uniprot pos
for uniA, uniB, pdb, chainA, chainB, iresA, iresB in tqdm_notebook(selections):
    pos_mapA = pos_maps[pdb, chainA, uniA]
    pos_mapB = pos_maps[pdb, chainB, uniB]
    
    pdb_df = my.pdb2df(pdb)
    
    pdb_df = pdb_df[pdb_df["Data Type"] == "ATOM"]
    pdb_df = pdb_df[pdb_df["Chain"].map(lambda x: x == chainA or x == chainB)]
    def do(x):
        chain, pos = x
        try:
            if(chain == chainA):
                return pos_mapA[str(pos)]
            else:
                return pos_mapB[str(pos)]
        except:
            return -pos
    pdb_df["Residue ID"] = pdb_df[["Chain", "Residue ID"]].apply(do, axis=1)
    
    my.df2pdb("reindexed_structures/{0}_{1}.pdb".format(uniA, uniB), pdb_df)
# Out:
# HBox(children=(IntProgress(value=0, max=50), HTML(value=u'')))
# WARNING: PDB lines do not match expectation (length 81, 80, 78, or 26 characters). Observed length set([79])
# I do not know why this is happening, maybe consult the PDB format summary again (http://www.cgl.ucsf.edu/chimera/docs/UsersGuide/tutorials/pdbintro.html)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import normalize

# %%
def x_rotation_matrix(theta):
    return np.array([1,              0,              0,
                     0,              np.cos(theta),  -np.sin(theta),
                     0,              np.sin(theta),  np.cos(theta)
                    ]).reshape((3, 3))
# FUNCTION END

def y_rotation_matrix(theta):
    return np.array([np.cos(theta),  0,              np.sin(theta),
                     0,              1,              0,
                     -np.sin(theta), 0,              np.cos(theta)
                    ]).reshape((3, 3))
# FUNCTION END

def z_rotation_matrix(theta):
    return np.array([np.cos(theta),  -np.sin(theta), 0,
                     np.sin(theta),  np.cos(theta), 0,
                     0,               0,             1
                    ]).reshape((3, 3))
# FUNCTION END

def rotate(xyz, theta_x, theta_y, theta_z, origin=np.array([0, 0, 0]), return_function=True):
    rot_matx = x_rotation_matrix(theta_x)
    rot_maty = y_rotation_matrix(theta_y)
    rot_matz = z_rotation_matrix(theta_z)
    
    if(return_function):
        return lambda x: rot_matz.dot(rot_maty.dot(rot_matx.dot(x - origin))) + origin
    return rot_matz.dot(rot_maty.dot(rot_matx.dot(xyz - origin))) + origin
# FUNCTION END

def translate(df, offset):
    df[["X", "Y", "Z"]] = df[["X", "Y", "Z"]] - offset
# FUNCTION END

def rotate_pdb(df, tx=None, ty=None, tz=None, origin=np.zeros(3), rot_func=None, angle_max=180):
    if(origin is "center"):
        origin = center_of_mass(pose, chain)
    if(tx is None):
        tx, ty, tz = (np.random.random(size=3) - 0.5)*angle_max*np.pi/180.0
    
    if(rot_func is None):
        rot_func = rotate(origin, tx, ty, tz, origin, True)
    
    # Apply the rotation
    tmp = np.concatenate(df[["X", "Y", "Z"]].apply(lambda x: rot_func(np.array(x)), axis=1).to_list(), axis=0).reshape(len(df), 3)
    df["X"] = np.round(tmp[:,0], 3)
    df["Y"] = np.round(tmp[:,1], 3)
    df["Z"] = np.round(tmp[:,2], 3)
# FUNCTION END

def orient_pdb(df, refA, refB):
    # Center
    translate(df, refA)
    refB = refB - refA
    
    # Generate First Rotation
    tmp = refB
    
    d_x = (tmp[0] - 0)
    d_z = (tmp[2] - 0)
    if(d_x*d_z != 0):
        sign = 1
        theta1 = sign*np.arctan(d_z / d_x)
        rot_mat1 = y_rotation_matrix(theta1)
    else:
        rot_mat1 = np.identity(3)
    
    # Generate Second Rotation
    tmp = rot_mat1.dot(tmp)
    
    d_x = tmp[0] - 0
    d_y = tmp[1] - 0
    if(d_x*d_y != 0):
        sign = -1#*[-1, 1][d_x*d_z <= 0]
        theta2 = -sign*np.arctan(d_x / d_y)
        rot_mat2 = z_rotation_matrix(theta2)
    else:
        rot_mat2 = np.identity(3)
    
    # Generate Third Rotation (to correct something?)
    tmp = rot_mat2.dot(tmp)
    
    if(tmp[1] < 0):
        theta3 = np.pi
        rot_mat3 = z_rotation_matrix(theta3)
    else:
        rot_mat3 = np.identity(3)
    
    tmp = rot_mat3.dot(tmp)
    
    # Apply the rotation
    rot_func = lambda x: rot_mat3.dot(rot_mat2.dot(rot_mat1.dot(np.array(x))))
    rotate_pdb(df, rot_func=rot_func)
# FUNCTION END

def rot_matrix_from_plane(ref1, ref2, ref3):
    # Center by reference 1
    original_delta = ref1.copy()

    # Rotate along Z axis so that ref 2 is at Y=0
    tmp = ref2 - original_delta

    d_x = tmp[0] - 0
    d_y = tmp[1] - 0
    if(d_x*d_y != 0):
        sign = -1#*[-1, 1][d_x*d_z <= 0]
        theta1 = sign*np.arctan(d_y / d_x)
        rot_mat1 = z_rotation_matrix(theta1)
    else:
        rot_mat1 = np.identity(3)

    # Roate along X axis so that ref 3 is at Z=0
    tmp = rot_mat1.dot(ref3 - original_delta)

    d_y = tmp[1] - 0
    d_z = tmp[2] - 0
    if(d_x*d_y != 0):
        sign = -1#*[-1, 1][d_x*d_z <= 0]
        theta2 = -sign*np.arctan(d_y / d_z)
        rot_mat2 = x_rotation_matrix(theta2)
    else:
        rot_mat2 = np.identity(3)

    # Return a function for this transformation
    return lambda x: rot_mat2.dot(rot_mat1.dot(x - original_delta))
# FUNCTION END

def orient_pdb_by_linear_regression(df, fit_col="Pred", up=True):
    # Generate Linear Regression Fit to the provided Label Column
    clf = LinearRegression()
    clf.fit(df[(~pd.isnull(df[fit_col]))&(df["Atom Name"] == "CA")][["X", "Y", "Z"]], df[(~pd.isnull(df[fit_col]))&(df["Atom Name"] == "CA")][fit_col])
    
    # Generate rotation matrix to match plane
    ref1 = np.array([-clf.intercept_/clf.coef_[0], 0, 0])
    ref2 = np.array([0, -clf.intercept_/clf.coef_[1], 0])
    ref3 = np.array([0, 0, -clf.intercept_/clf.coef_[2]])
    
    rot_func = rot_matrix_from_plane(ref1, ref2, ref3)
    
    # Apply Rotation and Center
    rotate_pdb(df, rot_func=rot_func)
    translate(df, df[["X", "Y", "Z"]].mean().values)
    
    # Final rotation to make sure interface is pointing the right direction
    if(up == True):
        if(clf.coef_[1] < 0):
            rotate_pdb(df, tx=np.deg2rad(180), ty=0, tz=0)
    else:
        if(clf.coef_[1] > 0):
            rotate_pdb(df, tx=np.deg2rad(180), ty=0, tz=0)
# FUNCTION END

# %%
# Pymol Imports

# %%
import __main__
__main__.pymol_argv = ['pymol','-cqk'] # Pymol: quiet and no GUI

import pymol
pymol.finish_launching()
from pymol import cmd as pymolCmd
pymolCmd.reinitialize()

# %%
# Reorient all structures so that interface faces are facing each other
for uniA, uniB, pdb, chainA, chainB, iresA, iresB in tqdm_notebook(selections):
    # Read Structure
    pdb_df = my.pdb2df("reindexed_structures/{0}_{1}.pdb".format(uniA, uniB))
    
    # Split by Chain
    A_df = pdb_df[pdb_df["Chain"] == chainA].copy()
    B_df = pdb_df[pdb_df["Chain"] == chainB].copy()
    
    if(len(A_df) == 0 or len(B_df) == 0):
        print "ERROR: no data for", uniA, uniB, pdb, chainA, chainB
        continue
    
    # Get Eclair Preds
    tmp = pd.read_sql_query("select * from eclair_predictions where P1 = '{0}' and P2 = '{1}'".format(*sorted([uniA, uniB])), mydb)
    prot = int(uniA > uniB)
    #print prot
    #print uniA, uniB
    tmp = tmp.set_index(["Prot", "Pos"])["Pred"].to_dict()
    
    # Assign Prediction Scores
    if(uniA != uniB):
        A_df["Pred"] = A_df["Residue ID"].map(lambda x: tmp[(prot, x)] if x > 0 else np.nan)
        B_df["Pred"] = B_df["Residue ID"].map(lambda x: tmp[(1-prot, x)] if x > 0 else np.nan)
    else:
        A_df["Pred"] = A_df["Residue ID"].map(lambda x: tmp[(0, x)] if x > 0 else np.nan)
        B_df["Pred"] = B_df["Residue ID"].map(lambda x: tmp[(0, x)] if x > 0 else np.nan)
    
    A_df_orig = A_df.copy()
    B_df_orig = B_df.copy()
    
    # Begin Reorientation
    
    # Handle Chain A
    #centroid_A = A_df[["X", "Y", "Z"]].mean().values
    #ires_centroid_A = A_df[(A_df["Atom Name"] == "CA")&(~pd.isnull(A_df["Pred"]))][["X", "Y", "Z", "Pred"]].apply(lambda x: np.array(x[:3])*x[3], axis=1).sum() / A_df[(A_df["Atom Name"] == "CA")&(~pd.isnull(A_df["Pred"]))]["Pred"].sum()
    
    #orient_pdb(A_df, centroid_A, ires_centroid_A)
    orient_pdb_by_linear_regression(A_df, up=True)
    
    
    # Handle Chain B
    #centroid_B = B_df[["X", "Y", "Z"]].mean().values
    #ires_centroid_B = B_df[(B_df["Atom Name"] == "CA")&(~pd.isnull(B_df["Pred"]))][["X", "Y", "Z", "Pred"]].apply(lambda x: np.array(x[:3])*x[3], axis=1).sum() / B_df[(B_df["Atom Name"] == "CA")&(~pd.isnull(B_df["Pred"]))]["Pred"].sum()

    #orient_pdb(B_df, centroid_B, ires_centroid_B)
    orient_pdb_by_linear_regression(B_df, up=False)
    #rotate_pdb(B_df, tx=np.deg2rad(180), ty=0, tz=0)
    
    # Final Translation to separate chains by 5 A
    translate(A_df, np.array([0, A_df["Y"].max() + 2.5, 0]))
    translate(B_df, np.array([0, B_df["Y"].min() - 2.5, 0]))
    
    # ADD CODE TO OPTIMZIE ROTATION ALONG Y AXIS (ONLY IN CHAIN B)
    
    # Record Centroid Locations
    #centroid_A = A_df[["X", "Y", "Z"]].mean().values
    ires_centroid_A = A_df[(A_df["Atom Name"] == "CA")&(~pd.isnull(A_df["Pred"]))][["X", "Y", "Z", "Pred"]].apply(lambda x: np.array(x[:3])*x[3], axis=1).sum() / A_df[(A_df["Atom Name"] == "CA")&(~pd.isnull(A_df["Pred"]))]["Pred"].sum()
    #
    #centroid_B = B_df[["X", "Y", "Z"]].mean().values
    ires_centroid_B = B_df[(B_df["Atom Name"] == "CA")&(~pd.isnull(B_df["Pred"]))][["X", "Y", "Z", "Pred"]].apply(lambda x: np.array(x[:3])*x[3], axis=1).sum() / B_df[(B_df["Atom Name"] == "CA")&(~pd.isnull(B_df["Pred"]))]["Pred"].sum()
    
    my.df2pdb("Test1.pdb".format(uniA, uniB), pd.concat([A_df, B_df]))
    
    # Make sure X:Z centorids of the Interfaces Line Up
    translate(A_df, np.array([ires_centroid_A[0], 0, ires_centroid_A[2]]))
    translate(B_df, np.array([ires_centroid_B[0], 0, ires_centroid_B[2]]))
    
    my.df2pdb("Test2.pdb".format(uniA, uniB), pd.concat([A_df, B_df]))
    

    # Save Reoriented Structures
    my.df2pdb("oriented_structures/{0}_{1}.pdb".format(uniA, uniB), pd.concat([A_df, B_df]))
    
    
    
    # Create Pymol Session
    pymolCmd.reinitialize()
    
    # Load Original Structure
    name = "{0}_{1}".format(uniA, uniB)
    pymolCmd.load("reindexed_structures/{0}.pdb".format(name), name + "_RAW")
    
    my.df2pdb("oriented_structures/{0}_{1}_A.pdb".format(uniA, uniB), A_df)
    my.df2pdb("oriented_structures/{0}_{1}_B.pdb".format(uniA, uniB), B_df)
    
    # Load Reoriented Structures
    pymolCmd.load("oriented_structures/{0}_A.pdb".format(name), name + "_A")
    pymolCmd.load("oriented_structures/{0}_B.pdb".format(name), name + "_B")
    
    
    # Color By Prediction
    cmapA = cm.get_cmap('Greens')   
    cmapB = cm.get_cmap('Blues')
    
    for resi, pred in A_df[["Residue ID", "Pred"]].drop_duplicates().values:
        if(np.isnan(pred)):
            pred = 0
        pymolCmd.color(matplotlib.colors.rgb2hex(cmapA(float(pred))[:3]).replace("#", "0x"), "{0}_A and resi {2}".format(name, chainA, int(resi)))
        pymolCmd.color(matplotlib.colors.rgb2hex(cmapA(float(pred))[:3]).replace("#", "0x"), "{0}_RAW and chain {1} and resi {2}".format(name, chainA, int(resi)))
    
    for resi, pred in B_df[["Residue ID", "Pred"]].drop_duplicates().values:
        if(np.isnan(pred)):
            pred = 0
        pymolCmd.color(matplotlib.colors.rgb2hex(cmapB(float(pred))[:3]).replace("#", "0x"), "{0}_B and resi {2}".format(name, chainB, int(resi)))
        pymolCmd.color(matplotlib.colors.rgb2hex(cmapB(float(pred))[:3]).replace("#", "0x"), "{0}_RAW and chain {1} and resi {2}".format(name, chainB, int(resi)))
    
    
    # Align Raw Structure to A
    pymolCmd.align("{0}_RAW and chain {1}".format(name, chainA), "{0}_A".format(name))
    
    # Save Structure Session
    pymolCmd.save("PyMolSessions/{0}.pse".format(name))
    
    #mins = 10*np.ceil(np.abs(A_df[["X", "Y", "Z"]].min() / 10))*(1-2*(A_df[["X", "Y", "Z"]].min() < 0)) - 20
    #maxes = 10*np.ceil(np.abs(A_df[["X", "Y", "Z"]].max() / 10))*(1-2*(A_df[["X", "Y", "Z"]].max() < 0)) + 20
    #clf = LinearRegression()
    #clf.fit(A_df[(~pd.isnull(A_df["Pred"]))&(A_df["Atom Name"] == "CA")][["X", "Y", "Z"]], A_df[(~pd.isnull(A_df["Pred"]))&(A_df["Atom Name"] == "CA")]["Pred"])
    #print uniA, uniB, "A", clf.coef_
    #
    ## Add colored point cloud
    #for x in tqdm_notebook(range(int(mins[0]), int(maxes[0])+1, 10)):
    #    for y in range(int(mins[1]), int(maxes[1])+1, 10):
    #        for z in range(int(mins[2]), int(maxes[2])+1, 10):
    #            pred2 = clf.predict(np.array([x, y, z]).reshape((1, 3)))
    #            c = matplotlib.colors.rgb2hex(cmapA(float(pred2))[:3]).replace("#", "0x")
    #            pymolCmd.pseudoatom("A_{0}_{1}_{2}".format(x, y, z), pos=[x, y, z], color=c)
    
    
    #mins = 10*np.ceil(np.abs(B_df[["X", "Y", "Z"]].min() / 10))*(1-2*(B_df[["X", "Y", "Z"]].min() < 0)) - 20
    #maxes = 10*np.ceil(np.abs(B_df[["X", "Y", "Z"]].max() / 10))*(1-2*(B_df[["X", "Y", "Z"]].max() < 0)) + 20
    #clf = LinearRegression()
    #clf.fit(B_df[(~pd.isnull(B_df["Pred"]))&(B_df["Atom Name"] == "CA")][["X", "Y", "Z"]], B_df[(~pd.isnull(B_df["Pred"]))&(B_df["Atom Name"] == "CA")]["Pred"])
    #print uniA, uniB, "B", clf.coef_
    #
    ## Add colored point cloud
    #for x in tqdm_notebook(range(int(mins[0]), int(maxes[0])+1, 10)):
    #    for y in range(int(mins[1]), int(maxes[1])+1, 10):
    #        for z in range(int(mins[2]), int(maxes[2])+1, 10):
    #            pred2 = clf.predict(np.array([x, y, z]).reshape((1, 3)))
    #            c = matplotlib.colors.rgb2hex(cmapB(float(pred2))[:3]).replace("#", "0x")
    #            pymolCmd.pseudoatom("B_{0}_{1}_{2}".format(x, y, z), pos=[x, y, z], color=c)

    
    
    
    
    
    continue
    
    # Load Original / Reoriented Structure
    name = "{0}_{1}".format(uniA, uniB)
    pymolCmd.load("reindexed_structures/{0}.pdb".format(name), name + "_RAW")
    pymolCmd.load("oriented_structures/{0}.pdb".format(name), name + "_ORIENTED")
    
    # Color By Prediction Score
    cmapA = cm.get_cmap('Blues')
    cmapB = cm.get_cmap('Greens')
    
    for resi, pred in A_df[["Residue ID", "Pred"]].drop_duplicates().values:
        if(np.isnan(pred)):
            pred = 0
        pymolCmd.color(matplotlib.colors.rgb2hex(cmapA(float(pred))[:3]).replace("#", "0x"), "{0}_RAW and chain {1} and resi {2}".format(name, chainA, int(resi)))
        pymolCmd.color(matplotlib.colors.rgb2hex(cmapA(float(pred))[:3]).replace("#", "0x"), "{0}_ORIENTED and chain {1} and resi {2}".format(name, chainA, int(resi)))
    
    for resi, pred in B_df[["Residue ID", "Pred"]].drop_duplicates().values:
        if(np.isnan(pred)):
            pred = 0
        pymolCmd.color(matplotlib.colors.rgb2hex(cmapB(float(pred))[:3]).replace("#", "0x"), "{0}_RAW and chain {1} and resi {2}".format(name, chainB, int(resi)))
        pymolCmd.color(matplotlib.colors.rgb2hex(cmapB(float(pred))[:3]).replace("#", "0x"), "{0}_ORIENTED and chain {1} and resi {2}".format(name, chainB, int(resi)))
    
    # Visualize the Centroids
    #pymolCmd.pseudoatom("ORIENTED_A_centroid", pos=list(centroid_A))
    #pymolCmd.pseudoatom("ORIENTED_A_ires_centroid", pos=list(ires_centroid_A))
    #pymolCmd.pseudoatom("ORIENTED_B_centroid", pos=list(centroid_B))
    #pymolCmd.pseudoatom("ORIENTED_B_ires_centroid", pos=list(ires_centroid_B))
    #
    #centroid_A = A_df_orig[["X", "Y", "Z"]].mean().values
    #ires_centroid_A = A_df_orig[(A_df_orig["Atom Name"] == "CA")&(~pd.isnull(A_df_orig["Pred"]))][["X", "Y", "Z", "Pred"]].apply(lambda x: np.array(x[:3])*x[3], axis=1).sum() / A_df_orig[(A_df_orig["Atom Name"] == "CA")&(~pd.isnull(A_df_orig["Pred"]))]["Pred"].sum()
    #
    #centroid_B = B_df_orig[["X", "Y", "Z"]].mean().values
    #ires_centroid_B = B_df_orig[(B_df_orig["Atom Name"] == "CA")&(~pd.isnull(B_df_orig["Pred"]))][["X", "Y", "Z", "Pred"]].apply(lambda x: np.array(x[:3])*x[3], axis=1).sum() / B_df_orig[(B_df_orig["Atom Name"] == "CA")&(~pd.isnull(B_df_orig["Pred"]))]["Pred"].sum()
    
    #pymolCmd.pseudoatom("A_centroid", pos=list(centroid_A))
    #pymolCmd.pseudoatom("A_ires_centroid", pos=list(ires_centroid_A))
    #pymolCmd.pseudoatom("B_centroid", pos=list(centroid_B))
    #pymolCmd.pseudoatom("B_ires_centroid", pos=list(ires_centroid_B))
    
    # Save the Sessions
    pymolCmd.save("PyMolSessions/{0}.pse".format(name))
# Out:
# HBox(children=(IntProgress(value=0, max=50), HTML(value=u'')))
# ERROR: no data for P68871 P69905 1XZ2 B C
# ERROR: no data for P20248 P24941 3EOC D C
# ERROR: no data for P03372 Q15596 5DXB A D
# ERROR: no data for P68871 P69905 1SDK B C
# ERROR: no data for P68871 P69905 1XZU B A
# ERROR: no data for P68871 P69905 1QSH D A

# %% [markdown]
# # COVID Predictions

# %%
# Read ECLAIR Preds
inter2preds = glob.glob("[REDACTED_PATH]/Collaborators/Eclair_Runs/2020_04_22_COVID19_Human_Interactome/Predictions/*")
inter2preds = {os.path.basename(x).split(".")[0]:pd.read_pickle(x) for x in inter2preds}

# %%
# Read Interactions
interactions = pd.read_csv("[REDACTED_PATH]/Collaborators/Eclair_Runs/2020_04_22_COVID19_Human_Interactome/Interactions.txt", names=["P1", "P2"], sep="\t")

# %%
# Select Homology Models for COVID Protein
#interactions["P1 PDB"] = interactions["P1"].map(lambda x: glob.glob("[REDACTED_PATH]/Collaborators/Lab_Member_Requests/Haiyuan/2020_03_27_COVID19_3DInteractome/modelling_test/{0}.*pdb".format(x.replace("COVID19", "")))[0] if glob.glob("[REDACTED_PATH]/Collaborators/Lab_Member_Requests/Haiyuan/2020_03_27_COVID19_3DInteractome/modelling_test/{0}.*pdb".format(x.replace("COVID19", ""))) else np.nan)
#interactions.ix[interactions["P1"] == "COVID19nsp5C145A", "P1 PDB"] = "[REDACTED_PATH]/Collaborators/Lab_Member_Requests/Haiyuan/2020_03_27_COVID19_3DInteractome/modelling_test/nsp5_C145A.B99990001.pdb"

interactions["P1 PDB"] = interactions["P1"].map(lambda x: glob.glob("[REDACTED_PATH]/eclair/data/modbase/models/hash/{0}.pdb".format(x.replace("COVID19", "")))[0] if glob.glob("[REDACTED_PATH]/eclair/data/modbase/models/hash/{0}.pdb".format(x.replace("COVID19", ""))) else np.nan)
interactions.ix[interactions["P1"] == "COVID19nsp5C145A", "P1 PDB"] = glob.glob("[REDACTED_PATH]/eclair/data/modbase/models/hash/nsp5_C145A.pdb")[0]
# Out:
# [REDACTED_PATH]/.conda/envs/jp/lib/python2.7/site-packages/ipykernel/__main__.py:6: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated

# %%
# Select Best PDB Model for Human Protein (best overlap with ECLAIR Predictions)
def get_best_pdb(cov, uni):
    # First Fetch ECLAIR Predictions
    pair = "_".join(sorted([cov, uni]))
    preds = inter2preds[pair]
    preds = preds[preds["Prot"] == (uni > cov)].set_index("Pos")["Pred"].to_dict()
    
    
    tmp = sifts[sifts["UniProt"] == uni][["PDB", "Chain", "UniProt", "MappableResInPDBChainOnUniprotBasis"]].copy()
    if(len(tmp) == 0):
        return np.nan, np.nan
    elif(len(tmp) == 1):
        return tmp[["PDB", "Chain"]].values[0]
    
    
    tmp["Len"] = tmp["MappableResInPDBChainOnUniprotBasis"].map(lambda x: len(unzip_res_range(x)))
    tmp["Weighted_Len"] = tmp["MappableResInPDBChainOnUniprotBasis"].map(lambda x:sum([preds[int(x)] for x in unzip_res_range(x)]))
    
    tmp.sort_values(["Weighted_Len", "Len"], ascending=False)
    
    return tmp[["PDB", "Chain"]].values[0]    
# FUNCTION END
tmp = interactions[["P1", "P2"]].apply(lambda x: get_best_pdb(*x), axis=1)
interactions["P2 PDB"] = [x[0] for x in tmp]
interactions["P2 Chain"] = [x[1] for x in tmp]

# %%
print len(interactions[(~pd.isnull(interactions["P1 PDB"]))&(~pd.isnull(interactions["P2 PDB"]))])
# Out:
# 112

# %%
# Add in Modbase Models where no PDB structure available
modbase = pd.read_csv("[REDACTED_PATH]/modbase/parsed_files/all_modbase_models.txt", sep="\t")
modbase[modbase["modpipe_quality_score"] >= 1.1].drop_duplicates("uniprot")

uni2modbase = modbase.set_index("uniprot")["modbase_modelID"].map(lambda x: ("[REDACTED_PATH]/modbase/data/hash/{0}.pdb".format(x))).to_dict()

interactions.ix[pd.isnull(interactions["P2 PDB"]), "P2 Chain"] = " "
interactions.ix[pd.isnull(interactions["P2 PDB"]), "P2 PDB"] = interactions.ix[pd.isnull(interactions["P2 PDB"]), "P2"].map(lambda x: uni2modbase[x] if x in uni2modbase else np.nan)
# Out:
# [REDACTED_PATH]/.conda/envs/jp/lib/python2.7/site-packages/ipykernel/__main__.py:7: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
# [REDACTED_PATH]/.conda/envs/jp/lib/python2.7/site-packages/ipykernel/__main__.py:8: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated

# %%
print len(interactions[(~pd.isnull(interactions["P1 PDB"]))&(~pd.isnull(interactions["P2 PDB"]))])
# Out:
# 255

# %%
# COVID Proteins were already indexed for ECLAIR, just copy them here
f2f = dict()
for f in tqdm_notebook(interactions["P1 PDB"].unique()):
    if(pd.isnull(f)):
        f2f[f] = f
        continue
    os.system("cp {0} reindexed_structures/{1}".format(f, os.path.basename(f)))
    f2f[f] = "reindexed_structures/{0}".format(os.path.basename(f))
# Out:
# HBox(children=(IntProgress(value=0, max=20), HTML(value=u'')))

# %%
# Reindex structures so they are numbered by Uniprot pos
for uni, pdb, chain in tqdm_notebook(interactions[["P2", "P2 PDB", "P2 Chain"]].values):
    if(pd.isnull(pdb)):
        continue
    
    # Handle Modbase Structures (should already be indexed, just copy)
    if(chain == " "):
        os.system("cp {0} reindexed_structures/{1}".format(pdb, os.path.basename(pdb)))
        f2f[pdb] = "reindexed_structures/{0}".format(os.path.basename(pdb))
        continue
    
    pos_map = pos_maps[pdb, chain, uni]
    
    pdb_df = my.pdb2df(pdb)
    pdb_df = pdb_df[pdb_df["Data Type"] == "ATOM"]
    pdb_df = pdb_df[pdb_df["Chain"] == chain]
    def do(x):
        chain, pos = x
        try:
            return pos_map[str(pos)]
        except:
            return -pos
    pdb_df["Residue ID"] = pdb_df[["Chain", "Residue ID"]].apply(do, axis=1)
    
    my.df2pdb("reindexed_structures/{0}_{1}_{2}.pdb".format(uni, pdb, chain), pdb_df)
    f2f[pdb] = "reindexed_structures/{0}_{1}_{2}.pdb".format(uni, pdb, chain)
# Out:
# HBox(children=(IntProgress(value=0, max=332), HTML(value=u'')))
# [REDACTED_PATH]/bin/helper.py:3756: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.header = header
# [REDACTED_PATH]/bin/helper.py:3757: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.tailer = tailer

# %%
interactions["P1 PDB"] = interactions["P1 PDB"].map(lambda x: f2f[x])
interactions["P2 PDB"] = interactions["P2 PDB"].map(lambda x: f2f[x])

# %%
from matplotlib import cm

# %%
# Reorient all structures so that interface faces are facing each other
for uniA, uniB, pdbA, pdbB, chainB in tqdm_notebook(interactions[["P1", "P2", "P1 PDB", "P2 PDB", "P2 Chain"]].values):
    chainA = " "
    
    if(pd.isnull(pdbA) or pd.isnull(pdbB)):
        continue
    
    # Read Structures
    A_df = my.pdb2df(pdbA)
    if(not chainA == " "):
        A_df = A_df[A_df["Chain"] == chainA].copy()
    
    B_df = my.pdb2df(pdbB)
    if(not chainB == " "):
        B_df = B_df[B_df["Chain"] == chainB].copy()
    
    if(len(A_df) == 0 or len(B_df) == 0):
        print "ERROR: no data for", uniA, uniB, pdbA, pdbB, chainA, chainB, len(A_df), len(B_df)
        continue
    
    # Get Eclair Preds
    tmp = inter2preds["_".join(sorted([uniA, uniB]))]
    tmp = tmp.set_index(["Prot", "Pos"])["Pred"].to_dict()
    prot = int(uniA > uniB)
    
    # Assign Prediction Scores
    if(uniA != uniB):
        A_df["Pred"] = A_df["Residue ID"].map(lambda x: tmp[(prot, x)] if x > 0 else np.nan)
        B_df["Pred"] = B_df["Residue ID"].map(lambda x: tmp[(1-prot, x)] if x > 0 else np.nan)
    else:
        A_df["Pred"] = A_df["Residue ID"].map(lambda x: tmp[(0, x)] if x > 0 else np.nan)
        B_df["Pred"] = B_df["Residue ID"].map(lambda x: tmp[(0, x)] if x > 0 else np.nan)
    
    
    # Begin Reorientation
    
    # Handle Chain A
    orient_pdb_by_linear_regression(A_df, up=True)
    
    # Handle Chain B
    orient_pdb_by_linear_regression(B_df, up=False)
    
    # Final Translation to separate chains by 5 A
    translate(A_df, np.array([0, A_df["Y"].max() + 2.5, 0]))
    translate(B_df, np.array([0, B_df["Y"].min() - 2.5, 0]))
    
    # ADD CODE TO OPTIMZIE ROTATION ALONG Y AXIS (ONLY IN CHAIN B)
    
    
    # Record Centroid Locations
    ires_centroid_A = A_df[(A_df["Atom Name"] == "CA")&(~pd.isnull(A_df["Pred"]))][["X", "Y", "Z", "Pred"]].apply(lambda x: np.array(x[:3])*x[3], axis=1).sum() / A_df[(A_df["Atom Name"] == "CA")&(~pd.isnull(A_df["Pred"]))]["Pred"].sum()
    ires_centroid_B = B_df[(B_df["Atom Name"] == "CA")&(~pd.isnull(B_df["Pred"]))][["X", "Y", "Z", "Pred"]].apply(lambda x: np.array(x[:3])*x[3], axis=1).sum() / B_df[(B_df["Atom Name"] == "CA")&(~pd.isnull(B_df["Pred"]))]["Pred"].sum()
    
    # Make sure X:Z centorids of the Interfaces Line Up
    translate(A_df, np.array([ires_centroid_A[0], 0, ires_centroid_A[2]]))
    translate(B_df, np.array([ires_centroid_B[0], 0, ires_centroid_B[2]]))
    
    # Save Reoriented Structures
    A_df["Chain"] = "A"
    B_df["Chain"] = "B"
    my.df2pdb("oriented_structures/{0}_{1}.pdb".format(uniA, uniB), pd.concat([A_df, B_df]))
    my.df2pdb("oriented_structures/{0}_{1}_A.pdb".format(uniA, uniB), A_df)
    my.df2pdb("oriented_structures/{0}_{1}_B.pdb".format(uniA, uniB), B_df)
    
    
    # Create Pymol Session
    pymolCmd.reinitialize()
    
    # Load Original Structure
    name = "{0}_{1}".format(uniA, uniB)
    
    # Load Reoriented Structures
    pymolCmd.load("oriented_structures/{0}_A.pdb".format(name), name + "_A")
    pymolCmd.load("oriented_structures/{0}_B.pdb".format(name), name + "_B")
    
    
    # Color By Prediction
    cmapA = cm.get_cmap('Greens')   
    cmapB = cm.get_cmap('Blues')
    
    for resi, pred in A_df[["Residue ID", "Pred"]].drop_duplicates().values:
        if(np.isnan(pred)):
            pred = 0
        pymolCmd.color(matplotlib.colors.rgb2hex(cmapA(float(pred))[:3]).replace("#", "0x"), "{0}_A and resi {2}".format(name, "A", int(resi)))
        
    for resi, pred in B_df[["Residue ID", "Pred"]].drop_duplicates().values:
        if(np.isnan(pred)):
            pred = 0
        pymolCmd.color(matplotlib.colors.rgb2hex(cmapB(float(pred))[:3]).replace("#", "0x"), "{0}_B and resi {2}".format(name, "B", int(resi)))
    
    # Save Structure Session
    pymolCmd.save("PyMolSessions/{0}.pse".format(name))
# Out:
# HBox(children=(IntProgress(value=0, max=332), HTML(value=u'')))
# ERROR: no data for COVID19nsp13 Q08379 reindexed_structures/nsp13.pdb reindexed_structures/Q9BQQ3_4REY_A.pdb   B 4684 0
# ERROR: no data for COVID19nsp4 P62072 reindexed_structures/nsp4.pdb reindexed_structures/Q9Y5J7_2BSK_A.pdb   B 3955 0
# ERROR: no data for COVID19nsp8 Q96B26 reindexed_structures/nsp8.pdb reindexed_structures/Q13868_2NN6_H.pdb   C 1486 0
# ERROR: no data for COVID19nsp8 Q9NQT4 reindexed_structures/nsp8.pdb reindexed_structures/Q13868_2NN6_H.pdb   D 1486 0
# ERROR: no data for COVID19nsp8 Q9NQT5 reindexed_structures/nsp8.pdb reindexed_structures/Q13868_2NN6_H.pdb   G 1486 0

# %%
def x_rotation_matrix(theta):
    return np.array([1,              0,              0,
                     0,              np.cos(theta),  -np.sin(theta),
                     0,              np.sin(theta),  np.cos(theta)
                    ]).reshape((3, 3))
# FUNCTION END

def y_rotation_matrix(theta):
    return np.array([np.cos(theta),  0,              np.sin(theta),
                     0,              1,              0,
                     -np.sin(theta), 0,              np.cos(theta)
                    ]).reshape((3, 3))
# FUNCTION END

def z_rotation_matrix(theta):
    return np.array([np.cos(theta),  -np.sin(theta), 0,
                     np.sin(theta),  np.cos(theta), 0,
                     0,               0,             1
                    ]).reshape((3, 3))
# FUNCTION END

def rotate(xyz, theta_x, theta_y, theta_z, origin=np.array([0, 0, 0]), return_function=True):
    rot_matx = x_rotation_matrix(theta_x)
    rot_maty = y_rotation_matrix(theta_y)
    rot_matz = z_rotation_matrix(theta_z)
    
    if(return_function):
        return lambda x: rot_matz.dot(rot_maty.dot(rot_matx.dot(x - origin))) + origin
    return rot_matz.dot(rot_maty.dot(rot_matx.dot(xyz - origin))) + origin
# FUNCTION END

def center_of_mass(pose, chain):
    center = np.zeros(3)
    total = 0
    for r in range(1, 1+pose.total_residue()):
        c = pose.pdb_info().pose2pdb(r).split()[-1]
        if(c != chain):
            continue
        center += np.array(pose.residue(r).xyz("CA"))
        total += 1
    
    return center / float(total)
# FUNCTION END

def translate_chain(pose, chain, xyz):
    # Apply translation vector
    delta_xyz = rosetta.numeric.xyzVector_double_t(*xyz)
    for r in range(1, 1+pose.total_residue()):
        c = pose.pdb_info().pose2pdb(r).split()[-1]
        if(c != chain):
            continue
        
        for a in range(1, pose.residue(r).natoms() + 1):
            pose.residue(r).set_xyz(a, pose.residue(r).xyz(a) + delta_xyz)
# FUNCTION END

def rotate_chain(pose, chain, tx=None, ty=None, tz=None, origin=np.zeros(3), rot_func=None, angle_max=180):
    if(origin is "center"):
        origin = center_of_mass(pose, chain)
    if(tx is None):
        tx, ty, tz = (np.random.random(size=3) - 0.5)*angle_max*np.pi/180.0
    
    if(rot_func is None):
        rot_func = rotate(origin, tx, ty, tz, origin, True)
    
    for r in range(1, 1+pose.total_residue()):
        c = pose.pdb_info().pose2pdb(r).split()[-1]
        if(c != chain):
            continue
        
        for a in range(1, pose.residue(r).natoms() + 1):
            new_xyz = rot_func(np.array(pose.residue(r).xyz(a)))
            new_xyz = rosetta.numeric.xyzVector_double_t(*new_xyz)
            pose.residue(r).set_xyz(a, new_xyz)
# FUNCTION END

def random_translate_chain(pose, chain, magnitude=5, angle=5):
    # Generate random translation vector
    delta_xyz = np.array([random.gauss(magnitude, magnitude*0.25), 0, 0])
    delta_xyz = rotate(delta_xyz, np.random.random()*2*np.pi, np.random.random()*2*np.pi, np.random.random()*2*np.pi)
    
    # Apply translation vector
    delta_xyz = rosetta.numeric.xyzVector_double_t(*delta_xyz)
    for r in range(1, 1+pose.total_residue()):
        c = pose.pdb_info().pose2pdb(r).split()[-1]
        if(c != chain):
            continue
        
        for a in range(1, pose.residue(r).natoms() + 1):
            pose.residue(r).set_xyz(a, pose.residue(r).xyz(a) + delta_xyz)
    
    # Generate random rotation
    theta1, theta2, theta3 = random.gauss(0, angle)*np.pi/180.0, random.gauss(0, angle)*np.pi/180.0, random.gauss(0, angle)*np.pi/180.0
    origin = center_of_mass(pose, chain)
    for r in range(1, 1+pose.total_residue()):
        c = pose.pdb_info().pose2pdb(r).split()[-1]
        if(c != chain):
            continue
        
        for a in range(1, pose.residue(r).natoms() + 1):
            new_xyz = rotate(np.array(pose.residue(r).xyz(a)), theta1, theta2, theta3, origin=origin)
            new_xyz = rosetta.numeric.xyzVector_double_t(*new_xyz)
            pose.residue(r).set_xyz(a, new_xyz)
# FUNCTION END

# %%
from pyrosetta import *
from pyrosetta.toolbox import *
init()
# Out:
# PyRosetta-4 2020 [Rosetta PyRosetta4.Release.python27.linux 2020.11+release.ce6f14f37b41d7372ea79cca59fad6b33adc1596 2020-03-12T19:59:10] retrieved from: http://www.pyrosetta.org
# (C) Copyright Rosetta Commons Member Institutions. Created in JHU by Sergey Lyskov and PyRosetta Team.
# core.init: Checking for fconfig files in pwd and ./rosetta/flags
# core.init: Rosetta version: PyRosetta4.Release.python27.linux r249 2020.11+release.ce6f14f ce6f14f37b41d7372ea79cca59fad6b33adc1596 http://www.pyrosetta.org 2020-03-12T19:59:10
# core.init: command: PyRosetta -ex1 -ex2aro -database [REDACTED_PATH]/bin/pyrosetta/database
# basic.random.init_random_generator: 'RNG device' seed mode, using '/dev/urandom', seed=-1496668198 seed_offset=0 real_seed=-1496668198
# basic.random.init_random_generator: RandomGenerator:init: Normal mode, seed=-1496668198 RG_type=mt19937

# %%
import subprocess as sp

# %%
cleanATOM("oriented_structures/COVID19nsp10_O94973.pdb")
pose = pose_from_file("oriented_structures/COVID19nsp10_O94973.clean.pdb")
# Out:
# core.import_pose.import_pose: File 'oriented_structures/COVID19nsp10_O94973.clean.pdb' automatically determined to be of type PDB

# %%
import time

# %%
def run_dock(pdb_file, i_num, rot_x=30, rot_y=None, rot_z=30, trans_x=5, trans_y=0, trans_z=5, recp_chain="A", lig_chain="B"):
    # Clean Pose / Load Pose
    cleanATOM(pdb_file)
    pose = pose_from_file(pdb_file.replace(".pdb", ".clean.pdb"))
    
    # Apply Random Spin on Ligand Chain
    if(not rot_x is None):
        tx = min([np.random.normal(0, rot_x/2.5), rot_x], key=lambda x: abs(x))
    else:
        tx = np.random.random()*360
    tx = np.deg2rad(tx)
    if(not rot_y is None):
        ty = min([np.random.normal(0, rot_y/2.5), rot_x], key=lambda x: abs(x))
    else:
        ty = np.random.random()*360
    ty = np.deg2rad(ty)
    if(not rot_z is None):
        tz = min([np.random.normal(0, rot_z/2.5), rot_x], key=lambda x: abs(x))
    else:
        tz = np.random.random()*360
    tz = np.deg2rad(tz)
    rotate_chain(pose, lig_chain, tx=tx, ty=ty, tz=tz, origin=center_of_mass(pose, lig_chain))
    
    # Apply Random Translation on Ligand Chain
    dx = min([np.random.normal(0, trans_x/2.5), trans_x], key=lambda x: abs(x))
    dy = min([np.random.normal(0, trans_y/2.5), trans_x], key=lambda x: abs(x))
    dz = min([np.random.normal(0, trans_z/2.5), trans_x], key=lambda x: abs(x))
    translate_chain(pose, lig_chain, np.array([dx, dy, dz]))
    
    # Apply Random Spin Around Receptor Chain
    if(not rot_x is None):
        tx = min([np.random.normal(0, rot_x/2.5), rot_x], key=lambda x: abs(x))
    else:
        tx = np.random.random()*360
    tx = np.deg2rad(tx)
    if(not rot_y is None):
        ty = min([np.random.normal(0, rot_y/2.5), rot_x], key=lambda x: abs(x))
    else:
        ty = np.random.random()*360
    ty = np.deg2rad(ty)
    if(not rot_z is None):
        tz = min([np.random.normal(0, rot_z/2.5), rot_x], key=lambda x: abs(x))
    else:
        tz = np.random.random()*360
    tz = np.deg2rad(tz)
    rotate_chain(pose, lig_chain, tx=tx, ty=ty, tz=tz, origin=center_of_mass(pose, recp_chain))
    
    # Save Pose as tmp input file
    out_pdb = os.path.abspath("random_docking_inputs/{0}_{1}.pdb".format(os.path.basename(pdb_file).split(".")[0], i_num))
    pose.dump_file(out_pdb)
    
    # Generate Process to run docking
    cmd = "nice python Docking_Script.py --pdb_filename {0} --partners A_B --jobs 1 --job_output {1}".format(out_pdb, os.path.basename(out_pdb).split(".")[0])
    #print cmd
    p = sp.Popen(cmd, shell=True)
    
    return {"p":p, "cmd":cmd, "start_time":time.time(), "end_time":None, "in_f":pdb_file}
# FUNCTION END

# %%
i_num = 1
input_pdbs = [x for x in glob.glob("oriented_structures/*COVID19*.pdb") if len(os.path.basename(x).split("_")) == 2 and not "clean" in x]
finished_processes = []
processes = []

os.system("rm [REDACTED_PATH]/Collaborators/Resource_Maintenance/2020_04_27_Guided_Docking_Test/docking_outputs/*.in_progress")
while(True):
    print "Docking Iteration", i_num
    
    # Iterate over all Docking Inputs
    for pdb_file in tqdm_notebook(input_pdbs):
        if(os.path.exists("[REDACTED_PATH]/Collaborators/Resource_Maintenance/2020_04_27_Guided_Docking_Test/docking_outputs/{0}_{1}_0.pdb".format(os.path.basename(pdb_file).split(".")[0], i_num))):
            continue
        # Update Max_Processes from File
        try:
            max_processes = int(my.easyReadLines("max_cores")[0])
        except:
            print "max_cores file formatted incorrectly"
            max_processes = 30
        
        # Make Block new jobs if too many running already
        while(True):
            if(len(processes) <= max_processes):
                p = run_dock(pdb_file, i_num)
                processes.append(p)
                break
            else:
                new_processes = []
                for p in processes:
                    if(p["p"].poll() is None):
                        new_processes.append(p)
                    elif(p["p"].poll() != 0):
                        p["end_time"] = time.time()
                        print "Error", p["p"].poll()
                        print "cmd:", p["cmd"]
                        print "RunTime:", (p["end_time"] - p["start_time"])
                        print
                        finished_processes.append(p)
                    else:
                        p["end_time"] = time.time()
                        print "Finished Docking", p["in_f"], "in", (p["end_time"] - p["start_time"])
                        finished_processes.append(p)
                processes = new_processes
                time.sleep(30)
    i_num += 1
# Out:
# Docking Iteration 1
# HBox(children=(IntProgress(value=0, max=250), HTML(value=u'')))
# 197/|/ 79%|| 197/250 [00:29<00:07,  6.79it/s]Docking Iteration 2
# HBox(children=(IntProgress(value=0, max=250), HTML(value=u'')))
# Docking Iteration 3
# HBox(children=(IntProgress(value=0, max=250), HTML(value=u'')))
# Docking Iteration 4
# HBox(children=(IntProgress(value=0, max=250), HTML(value=u'')))
# Finished Docking oriented_structures/COVID19orf8_P05556.pdb in 474.95126605
# Finished Docking oriented_structures/COVID19orf7a_Q7Z4Q2.pdb in 590.414237976
# Finished Docking oriented_structures/COVID19orf9c_Q6NXT6.pdb in 524.39854598
# Finished Docking oriented_structures/COVID19orf8_Q9H4F8.pdb in 523.533063173
# Finished Docking oriented_structures/COVID19orf8_Q6UW63.pdb in 611.945548773
# Finished Docking oriented_structures/COVID19nsp7_Q5JTV8.pdb in 685.160368919
# Finished Docking oriented_structures/COVID19orf8_Q08431.pdb in 135.676477194
# Finished Docking oriented_structures/COVID19nsp7_Q5VT66.pdb in 712.589363098
# Finished Docking oriented_structures/COVID19nsp1_Q99959.pdb in 707.10914588
# Finished Docking oriented_structures/COVID19orf9c_Q2PZI1.pdb in 130.14140296
#
# Docking Iteration 5
# HBox(children=(IntProgress(value=0, max=250), HTML(value=u'')))
# Finished Docking oriented_structures/COVID19orf9c_Q9Y276.pdb in 805.728705883
# Finished Docking oriented_structures/COVID19orf9c_Q86UT6.pdb in 801.678977013
# Finished Docking oriented_structures/COVID19orf9c_Q96K12.pdb in 119.827090025
# Finished Docking oriented_structures/COVID19nsp7_P62873.pdb in 930.67772603
# Finished Docking oriented_structures/COVID19orf9c_Q8TEQ8.pdb in 130.928827047
# Finished Docking oriented_structures/COVID19nsp7_P51148.pdb in 1078.58062005
# Finished Docking oriented_structures/COVID19nsp7_Q9NP72.pdb in 1041.89763284
# Finished Docking oriented_structures/COVID19orf9c_P33527.pdb in 1087.78267097
# Finished Docking oriented_structures/COVID19nsp7_Q8WVC6.pdb in 1160.99965596
# Finished Docking oriented_structures/COVID19nsp9_P61962.pdb in 525.253942013
# Finished Docking oriented_structures/COVID19orf8_P29122.pdb in 202.341947079
# Finished Docking oriented_structures/COVID19orf8_P26358.pdb in 1341.15544105
# Finished Docking oriented_structures/COVID19nsp8_Q92552.pdb in 1536.40815496
# Finished Docking oriented_structures/COVID19nsp7_Q8WTV0.pdb in 551.507982016
# Finished Docking oriented_structures/COVID19nsp2_Q6Y7W6.pdb in 1624.01903796
# Finished Docking oriented_structures/COVID19orf9b_P27448.pdb in 1594.64745116
# Finished Docking oriented_structures/COVID19orf8_Q9H488.pdb in 1736.43073201
# Finished Docking oriented_structures/COVID19nsp2_P16435.pdb in 1879.8716228
# Finished Docking oriented_structures/COVID19nsp10_Q96CW1.pdb in 1049.81823111
# Finished Docking oriented_structures/COVID19orf8_Q9H488.pdb in 1919.7995491
# Finished Docking oriented_structures/COVID19orf9c_Q9H845.pdb in 1131.94239616
# Finished Docking oriented_structures/COVID19nsp7_P61586.pdb in 679.981066942
# Finished Docking oriented_structures/COVID19nsp7_Q9H7Z7.pdb in 391.276997089
# Finished Docking oriented_structures/COVID19nsp7_Q5VT66.pdb in 405.569458008
# Finished Docking oriented_structures/COVID19orf8_Q9NXK8.pdb in 551.031772852
# Finished Docking oriented_structures/COVID19orf9b_P27448.pdb in 1048.32964802
# Finished Docking oriented_structures/COVID19orf9c_Q86UT6.pdb in 426.711487055
# Finished Docking oriented_structures/COVID19orf9c_Q96K12.pdb in 362.439239025
# Finished Docking oriented_structures/COVID19nsp9_P13984.pdb in 462.757572889
# Finished Docking oriented_structures/COVID19nsp9_Q99567.pdb in 2055.51136899
# Finished Docking oriented_structures/COVID19nsp9_Q8TD19.pdb in 336.261337996
# Finished Docking oriented_structures/COVID19orf9c_Q7Z2K6.pdb in 334.526582956
# Finished Docking oriented_structures/COVID19orf9c_Q6NXT4.pdb in 410.335915089
# Finished Docking oriented_structures/COVID19orf6_Q9NZJ7.pdb in 100.412329912
# Finished Docking oriented_structures/COVID19orf6_P78406.pdb in 1272.00131512
# Finished Docking oriented_structures/COVID19orf8_Q8N766.pdb in 2907.92783594
# Finished Docking oriented_structures/COVID19orf8_Q8IWF2.pdb in 159.107105017
# Finished Docking oriented_structures/COVID19orf8_Q9BZQ6.pdb in 568.709393024
# Finished Docking oriented_structures/COVID19nsp8_Q7L2J0.pdb in 1239.3061161
# Finished Docking oriented_structures/COVID19nsp2_O14975.pdb in 2741.66768599
# Finished Docking oriented_structures/COVID19nsp4_Q9BSF4.pdb in 1815.85294604
# Finished Docking oriented_structures/COVID19nsp13_Q7Z7A1.pdb in 2631.55606198
# Finished Docking oriented_structures/COVID19orf9b_Q9UL15.pdb in 155.370527983
# Finished Docking oriented_structures/COVID19nsp14_Q9NXA8.pdb in 2923.76618314
# Finished Docking oriented_structures/COVID19nsp8_Q9ULT8.pdb in 668.12958312
# Finished Docking oriented_structures/COVID19nsp7_P61026.pdb in 731.869302034
# Finished Docking oriented_structures/COVID19nsp7_Q8WUY8.pdb in 159.299335957
# Finished Docking oriented_structures/COVID19nsp7_Q13724.pdb in 411.579364061
# Finished Docking oriented_structures/COVID19orf8_Q8IV08.pdb in 223.897629023
# Finished Docking oriented_structures/COVID19nsp8_P09132.pdb in 381.022228003
# Finished Docking oriented_structures/COVID19orf9c_Q9Y6M9.pdb in 832.822545052
# Finished Docking oriented_structures/COVID19orf9c_Q9BQ95.pdb in 129.116819143
# Finished Docking oriented_structures/COVID19orf9c_Q96S52.pdb in 412.97232008
# Finished Docking oriented_structures/COVID19orf8_O76061.pdb in 440.677015066
# Finished Docking oriented_structures/COVID19nsp7_Q9BQE4.pdb in 154.793221951
# Finished Docking oriented_structures/COVID19nsp8_Q9BSC4.pdb in 4240.05282998
# Finished Docking oriented_structures/COVID19nsp4_Q2TAA5.pdb in 2362.70683908
# Finished Docking oriented_structures/COVID19orf8_Q96DZ1.pdb in 668.656218767
# Finished Docking oriented_structures/COVID19nsp8_Q9Y399.pdb in 876.496314049
# Finished Docking oriented_structures/COVID19nsp5C145A_P07203.pdb in 685.508853197
# Finished Docking oriented_structures/COVID19orf8_O14656.pdb in 434.081653118
# Finished Docking oriented_structures/COVID19nsp13_A7MCY6.pdb in 3347.51996303
# Finished Docking oriented_structures/COVID19nsp9_P61962.pdb in 448.488037825
# Finished Docking oriented_structures/COVID19nsp8_Q13868.pdb in 1784.16101003
# Finished Docking oriented_structures/COVID19nsp12_Q14157.pdb in 1823.01334095
# Finished Docking oriented_structures/COVID19nsp13_P31323.pdb in 1023.64680886
# Finished Docking oriented_structures/COVID19nsp7_O95573.pdb in 518.825127125
# Finished Docking oriented_structures/COVID19orf8_Q9Y4L1.pdb in 5195.51079392
# Finished Docking oriented_structures/COVID19orf9c_Q9GZU3.pdb in 368.6513412
# Finished Docking oriented_structures/COVID19nsp13_Q9BV19.pdb in 1014.07098985
# Finished Docking oriented_structures/COVID19nsp1_Q8NBJ5.pdb in 407.97221303
# Error 1
# cmd: nice python Docking_Script.py --pdb_filename [REDACTED_PATH]Collaborators/Resource_Maintenance/2020_04_27_Guided_Docking_Test/random_docking_inputs/COVID19nsp8_Q9HD40_5.pdb --partners A_B --jobs 1 --job_output COVID19nsp8_Q9HD40_5
# RunTime: 4243.59834313
#
# Finished Docking oriented_structures/COVID19nsp13_Q04726.pdb in 5444.57989502
# Finished Docking oriented_structures/COVID19nsp7_P61019.pdb in 824.564487934
# Error 1
# cmd: nice python Docking_Script.py --pdb_filename [REDACTED_PATH]Collaborators/Resource_Maintenance/2020_04_27_Guided_Docking_Test/random_docking_inputs/COVID19orf8_P05556_5.pdb --partners A_B --jobs 1 --job_output COVID19orf8_P05556_5
# RunTime: 662.86950016
#
# Finished Docking oriented_structures/COVID19nsp13_Q76N32.pdb in 1469.07051206
# Finished Docking oriented_structures/COVID19nsp7_P63218.pdb in 360.275266171
# Finished Docking oriented_structures/COVID19nsp13_Q7Z7A1.pdb in 1157.14179301
# Finished Docking oriented_structures/COVID19nsp10_O94973.pdb in 5814.15013289
# Finished Docking oriented_structures/COVID19nsp7_Q12907.pdb in 282.95945096
# Finished Docking oriented_structures/COVID19orf9c_Q12770.pdb in 123.142704964
# Finished Docking oriented_structures/COVID19nsp12_O95391.pdb in 4722.83483291
# Error 1
# cmd: nice python Docking_Script.py --pdb_filename [REDACTED_PATH]Collaborators/Resource_Maintenance/2020_04_27_Guided_Docking_Test/random_docking_inputs/COVID19nsp13_Q92995_5.pdb --partners A_B --jobs 1 --job_output COVID19nsp13_Q92995_5
# RunTime: 3600.35226107
#
# Finished Docking oriented_structures/COVID19nsp13_Q14789.pdb in 6173.680547
# Finished Docking oriented_structures/COVID19nsp7_Q5JTV8.pdb in 807.327674866
# Finished Docking oriented_structures/COVID19orf8_P00750.pdb in 521.927027941
# Finished Docking oriented_structures/COVID19orf9b_O75534.pdb in 524.797132015
# Finished Docking oriented_structures/COVID19orf8_Q99470.pdb in 275.22794795
# Finished Docking oriented_structures/COVID19orf8_P61916.pdb in 754.353257895
# Finished Docking oriented_structures/COVID19nsp2_P16435.pdb in 3503.01843905
# Finished Docking oriented_structures/COVID19nsp9_Q86YT6.pdb in 788.39745307
# Finished Docking oriented_structures/COVID19orf9c_Q8TEQ8.pdb in 165.400244951
# Finished Docking oriented_structures/COVID19nsp13_Q9BQS8.pdb in 1215.5773561
# Finished Docking oriented_structures/COVID19nsp13_O95684.pdb in 3020.96286106
# Finished Docking oriented_structures/COVID19nsp8_P82663.pdb in 342.42859602
# Finished Docking oriented_structures/COVID19orf8_P58166.pdb in 718.645701885
# Finished Docking oriented_structures/COVID19orf9b_Q7KZI7.pdb in 610.704310894
# Finished Docking oriented_structures/COVID19orf8_P28300.pdb in 483.562965155
# Finished Docking oriented_structures/COVID19nsp8_O96028.pdb in 1264.76692104
# Finished Docking oriented_structures/COVID19nsp13_Q04724.pdb in 2481.39554906
# Finished Docking oriented_structures/COVID19nsp13_Q9UHD2.pdb in 3425.33551192
# Finished Docking oriented_structures/COVID19nsp8_O76094.pdb in 1147.4468751
# Finished Docking oriented_structures/COVID19nsp13_P35241.pdb in 1135.14560986
# Finished Docking oriented_structures/COVID19orf8_Q96AY3.pdb in 586.69879508
# Finished Docking oriented_structures/COVID19orf8_Q96MM7.pdb in 655.189255953
# Error 1
# cmd: nice python Docking_Script.py --pdb_filename [REDACTED_PATH]Collaborators/Resource_Maintenance/2020_04_27_Guided_Docking_Test/random_docking_inputs/COVID19nsp1_Q99959_5.pdb --partners A_B --jobs 1 --job_output COVID19nsp1_Q99959_5
# RunTime: 2147.65352893
#
# Finished Docking oriented_structures/COVID19nsp8_Q8NEJ9.pdb in 818.385672808
# Finished Docking oriented_structures/COVID19nsp12_O43823.pdb in 4624.4099741
# Finished Docking oriented_structures/COVID19nsp10_Q969X5.pdb in 184.468966961
# Finished Docking oriented_structures/COVID19nsp7_P11233.pdb in 816.976613998
# Finished Docking oriented_structures/COVID19orf9c_Q9BVK2.pdb in 345.168064833
# Finished Docking oriented_structures/COVID19nsp9_Q8N0X7.pdb in 571.343012094
# Finished Docking oriented_structures/COVID19nsp15_P61970.pdb in 1605.60246301
# Finished Docking oriented_structures/COVID19orf8_Q96IV0.pdb in 663.647552967
# Finished Docking oriented_structures/COVID19nsp13_Q8TD10.pdb in 3318.63449812
# Error 1
# cmd: nice python Docking_Script.py --pdb_filename [REDACTED_PATH]Collaborators/Resource_Maintenance/2020_04_27_Guided_Docking_Test/random_docking_inputs/COVID19orf9c_Q5BJF2_5.pdb --partners A_B --jobs 1 --job_output COVID19orf9c_Q5BJF2_5
# RunTime: 979.439776897
#
# Finished Docking oriented_structures/COVID19nsp7_P21964.pdb in 351.615714073
# Finished Docking oriented_structures/COVID19orf9b_O14745.pdb in 412.378443003
#
# Docking Iteration 6
# HBox(children=(IntProgress(value=0, max=250), HTML(value=u'')))
# Finished Docking oriented_structures/COVID19nsp7_Q8N183.pdb in 506.986329079
# Finished Docking oriented_structures/COVID19nsp13_Q8IWJ2.pdb in 2346.561481
# Finished Docking oriented_structures/COVID19nsp8_P82675.pdb in 706.441822052
# Finished Docking oriented_structures/COVID19orf9b_Q9H2P9.pdb in 1172.72000504
# Finished Docking oriented_structures/COVID19nsp7_Q8NBX0.pdb in 412.617512941
# Finished Docking oriented_structures/COVID19nsp7_Q96A26.pdb in 380.377938032
# Finished Docking oriented_structures/COVID19nsp7_P62873.pdb in 1081.79391003
# Finished Docking oriented_structures/COVID19orf9c_Q9H3K2.pdb in 312.59779501
# Finished Docking oriented_structures/COVID19nsp1_P09884.pdb in 126.324621916
# Finished Docking oriented_structures/COVID19nsp13_Q9UJC3.pdb in 7111.42616606
# Finished Docking oriented_structures/COVID19nsp9_P35556.pdb in 168.734998941
# Finished Docking oriented_structures/COVID19nsp14_P12268.pdb in 3046.60288811
# Finished Docking oriented_structures/COVID19orf8_Q96F46.pdb in 1414.55413008
# Finished Docking oriented_structures/COVID19nsp13_Q5VU43.pdb in 8369.50183105
# Finished Docking oriented_structures/COVID19nsp4_Q9NVH1.pdb in 1093.69867611
# Finished Docking oriented_structures/COVID19nsp12_Q5T6F2.pdb in 4731.88314486
# Finished Docking oriented_structures/COVID19nsp12_Q6UUV7.pdb in 8753.247123
# Error 1
# cmd: nice python Docking_Script.py --pdb_filename [REDACTED_PATH]Collaborators/Resource_Maintenance/2020_04_27_Guided_Docking_Test/random_docking_inputs/COVID19orf8_Q9NYU1_2.pdb --partners A_B --jobs 1 --job_output COVID19orf8_Q9NYU1_2
# RunTime: 9667.91167998
#
# Finished Docking oriented_structures/COVID19nsp12_Q6UUV7.pdb in 9639.31900096
# Finished Docking oriented_structures/COVID19nsp9_Q96F45.pdb in 685.374567986
# Finished Docking oriented_structures/COVID19orf9b_Q9P0L2.pdb in 1576.69788504
# Finished Docking oriented_structures/COVID19orf8_Q13438.pdb in 728.255334854
# Finished Docking oriented_structures/COVID19orf8_O00469.pdb in 530.964265108
# Finished Docking oriented_structures/COVID19nsp8_Q4G0J3.pdb in 373.862900972
# Finished Docking oriented_structures/COVID19orf8_Q7Z4H8.pdb in 182.880337954
# Finished Docking oriented_structures/COVID19nsp13_Q8N4C6.pdb in 10276.852355
# Finished Docking oriented_structures/COVID19nsp2_Q6Y7W6.pdb in 3367.2721529
# Finished Docking oriented_structures/COVID19orf9b_Q9UKA9.pdb in 500.894120932
# Finished Docking oriented_structures/COVID19nsp7_P61006.pdb in 606.719499826
# Finished Docking oriented_structures/COVID19orf8_Q9BRN9.pdb in 574.050101995
# Finished Docking oriented_structures/COVID19nsp9_Q7Z3B4.pdb in 152.558722019
# Finished Docking oriented_structures/COVID19nsp5_Q92769.pdb in 2301.52069902
# Finished Docking oriented_structures/COVID19nsp9_Q9NZL9.pdb in 1428.68249297
# Error 1
# cmd: nice python Docking_Script.py --pdb_filename [REDACTED_PATH]Collaborators/Resource_Maintenance/2020_04_27_Guided_Docking_Test/random_docking_inputs/COVID19nsp10_O94973_5.pdb --partners A_B --jobs 1 --job_output COVID19nsp10_O94973_5
# RunTime: 9855.83602595
#
# Finished Docking oriented_structures/COVID19orf7a_Q7Z4Q2.pdb in 579.29847002
# Finished Docking oriented_structures/COVID19nsp15_P62330.pdb in 2039.01668787
# Finished Docking oriented_structures/COVID19orf8_Q99988.pdb in 243.16118598
# Finished Docking oriented_structures/COVID19nsp14_P06280.pdb in 4833.89514112
# Finished Docking oriented_structures/COVID19orf8_P12109.pdb in 470.529289007
# Finished Docking oriented_structures/COVID19orf9c_O76024.pdb in 452.301955938
# Error 1
# cmd: nice python Docking_Script.py --pdb_filename [REDACTED_PATH]Collaborators/Resource_Maintenance/2020_04_27_Guided_Docking_Test/random_docking_inputs/COVID19nsp9_Q9UBX5_6.pdb --partners A_B --jobs 1 --job_output COVID19nsp9_Q9UBX5_6
# RunTime: 991.205349922
#
# Finished Docking oriented_structures/COVID19nsp4_Q9Y5J6.pdb in 2233.75765395
# Error 1
# cmd: nice python Docking_Script.py --pdb_filename [REDACTED_PATH]Collaborators/Resource_Maintenance/2020_04_27_Guided_Docking_Test/random_docking_inputs/COVID19nsp8_Q96I59_6.pdb --partners A_B --jobs 1 --job_output COVID19nsp8_Q96I59_6
# RunTime: 1353.04477715
#
# Finished Docking oriented_structures/COVID19nsp1_P49642.pdb in 766.709565878
# Finished Docking oriented_structures/COVID19nsp12_Q9HAU0.pdb in 4028.53862119
# Finished Docking oriented_structures/COVID19orf9c_Q9NV92.pdb in 127.610683918
# Finished Docking oriented_structures/COVID19orf8_Q8IZ52.pdb in 162.142231941
# Finished Docking oriented_structures/COVID19nsp15_Q9H4P4.pdb in 1734.49875617
# Finished Docking oriented_structures/COVID19orf8_Q15818.pdb in 193.569370031
# Finished Docking oriented_structures/COVID19nsp2_Q2M389.pdb in 9785.16699195
# Finished Docking oriented_structures/COVID19orf8_Q9H488.pdb in 1512.77287006
# Finished Docking oriented_structures/COVID19nsp8_Q9H6F5.pdb in 698.401391029
# Finished Docking oriented_structures/COVID19nsp7_O00116.pdb in 2626.943542
# Finished Docking oriented_structures/COVID19nsp13_Q96CN9.pdb in 2732.41329694
# Finished Docking oriented_structures/COVID19nsp9_Q9BVL2.pdb in 553.579282999
# Finished Docking oriented_structures/COVID19orf8_Q6UW63.pdb in 225.980164051
# Finished Docking oriented_structures/COVID19nsp7_P51148.pdb in 566.189287901
# Finished Docking oriented_structures/COVID19nsp1_Q14181.pdb in 503.748282909
# Finished Docking oriented_structures/COVID19nsp13_P13861.pdb in 2828.468328
# Finished Docking oriented_structures/COVID19nsp10_Q96CW1.pdb in 939.954595804
# Finished Docking oriented_structures/COVID19nsp13_Q5VT06.pdb in 1231.35394406
# Finished Docking oriented_structures/COVID19nsp7_Q8WVC6.pdb in 844.714729071
# Finished Docking oriented_structures/COVID19nsp7_O43169.pdb in 441.843302965
# Finished Docking oriented_structures/COVID19nsp4_Q9Y5J7.pdb in 843.948467016
# Finished Docking oriented_structures/COVID19nsp12_Q96IZ5.pdb in 3877.57618022
# Error 1
# cmd: nice python Docking_Script.py --pdb_filename [REDACTED_PATH]Collaborators/Resource_Maintenance/2020_04_27_Guided_Docking_Test/random_docking_inputs/COVID19orf9c_Q9H845_5.pdb --partners A_B --jobs 1 --job_output COVID19orf9c_Q9H845_5
# RunTime: 5616.10531497
#
# Finished Docking oriented_structures/COVID19orf9c_Q86VR2.pdb in 385.179599047
# Finished Docking oriented_structures/COVID19nsp12_Q92615.pdb in 3453.01548982
# Finished Docking oriented_structures/COVID19orf8_P26358.pdb in 354.551900864
# Finished Docking oriented_structures/COVID19nsp9_P35658.pdb in 1803.49652982
# Finished Docking oriented_structures/COVID19nsp7_Q7LGA3.pdb in 1438.45462799
# Finished Docking oriented_structures/COVID19orf8_P0C7P0.pdb in 538.638998985
# Finished Docking oriented_structures/COVID19orf8_P15151.pdb in 352.810830832
# Finished Docking oriented_structures/COVID19orf9c_P55085.pdb in 248.300382853
# Finished Docking oriented_structures/COVID19nsp8_O95260.pdb in 1371.05831718
# Finished Docking oriented_structures/COVID19nsp12_A3KN83.pdb in 1811.65149212
# Finished Docking oriented_structures/COVID19nsp13_Q8N8E3.pdb in 9052.48097014
# Finished Docking oriented_structures/COVID19nsp7_Q96DA6.pdb in 382.898535013
# Finished Docking oriented_structures/COVID19nsp7_P51149.pdb in 709.82861495
# Finished Docking oriented_structures/COVID19nsp8_Q92552.pdb in 1374.47108912
# Finished Docking oriented_structures/COVID19nsp7_P61106.pdb in 554.951623917
# Finished Docking oriented_structures/COVID19nsp13_Q08117.pdb in 2339.71279287
# Finished Docking oriented_structures/COVID19orf8_Q9H4F8.pdb in 190.003580093
# Finished Docking oriented_structures/COVID19nsp4_Q8TEM1.pdb in 2890.85181999
# Finished Docking oriented_structures/COVID19nsp8_Q9BSC4.pdb in 1678.83851314
# Finished Docking oriented_structures/COVID19orf9c_Q9Y276.pdb in 125.844909906
# Finished Docking oriented_structures/COVID19nsp2_O60573.pdb in 4104.55296683
# Finished Docking oriented_structures/COVID19orf9c_O43292.pdb in 2458.42570305
# Finished Docking oriented_structures/COVID19orf9c_Q6NXT6.pdb in 180.179969072
# Finished Docking oriented_structures/COVID19nsp10_Q9HAV7.pdb in 472.234989166
# Finished Docking oriented_structures/COVID19orf8_Q9H8W4.pdb in 565.445941925
# Finished Docking oriented_structures/COVID19orf8_Q13443.pdb in 342.034361124
# Finished Docking oriented_structures/COVID19orf8_Q8N766.pdb in 2705.43414283
# Finished Docking oriented_structures/COVID19nsp9_P35555.pdb in 160.212369204
# Finished Docking oriented_structures/COVID19nsp12_O14874.pdb in 6662.94881606
# Finished Docking oriented_structures/COVID19orf9c_O00124.pdb in 131.044164896
# Finished Docking oriented_structures/COVID19nsp13_O95613.pdb in 9580.09813094
# Finished Docking oriented_structures/COVID19orf8_Q9NYU1.pdb in 4778.10576916
# Finished Docking oriented_structures/COVID19orf9b_O94826.pdb in 170.998675823
# Finished Docking oriented_structures/COVID19nsp7_Q8WTV0.pdb in 160.65277195
# Finished Docking oriented_structures/COVID19orf9b_O43633.pdb in 466.352965117
# Finished Docking oriented_structures/COVID19nsp13_Q66GS9.pdb in 2445.83800101
# Finished Docking oriented_structures/COVID19nsp5C145A_Q9NXH9.pdb in 485.323612928
# Finished Docking oriented_structures/COVID19nsp1_P49643.pdb in 710.370737076
# Error 1
# cmd: nice python Docking_Script.py --pdb_filename [REDACTED_PATH]Collaborators/Resource_Maintenance/2020_04_27_Guided_Docking_Test/random_docking_inputs/COVID19orf8_Q9Y4L1_5.pdb --partners A_B --jobs 1 --job_output COVID19orf8_Q9Y4L1_5
# RunTime: 9575.50653219
#
# Finished Docking oriented_structures/COVID19nsp7_P00387.pdb in 935.594136953
# Finished Docking oriented_structures/COVID19nsp13_Q14789.pdb in 9726.01520514
# Finished Docking oriented_structures/COVID19orf8_Q08431.pdb in 382.515861988
# Finished Docking oriented_structures/COVID19nsp13_Q08378.pdb in 9187.25214696
# Finished Docking oriented_structures/COVID19nsp8_O00566.pdb in 843.527951002
# Finished Docking oriented_structures/COVID19nsp2_Q5T1M5.pdb in 2786.55651903
# Finished Docking oriented_structures/COVID19nsp9_Q15056.pdb in 176.654922962
# Finished Docking oriented_structures/COVID19nsp13_Q04726.pdb in 2117.79713511
# Finished Docking oriented_structures/COVID19orf8_P29122.pdb in 168.458024979
# Finished Docking oriented_structures/COVID19nsp13_Q96SN8.pdb in 1348.70181799
# Finished Docking oriented_structures/COVID19orf9b_Q9H773.pdb in 439.87511611
# Finished Docking oriented_structures/COVID19nsp7_Q6ZRP7.pdb in 444.957596064
# Finished Docking oriented_structures/COVID19nsp8_P61011.pdb in 818.594521046
# Finished Docking oriented_structures/COVID19orf9c_Q9Y3A6.pdb in 556.127934933
# Finished Docking oriented_structures/COVID19nsp13_Q9Y2I6.pdb in 2790.25878501
# Finished Docking oriented_structures/COVID19nsp10_O94973.pdb in 2517.44915485
# Finished Docking oriented_structures/COVID19nsp8_Q9NY61.pdb in 639.654969215
# Finished Docking oriented_structures/COVID19orf9c_P33527.pdb in 818.544834137
# Finished Docking oriented_structures/COVID19nsp13_P17612.pdb in 4155.67938995
# Finished Docking oriented_structures/COVID19orf8_Q9UHI8.pdb in 466.921164036
# Finished Docking oriented_structures/COVID19orf6_P52948.pdb in 442.016712189
# Finished Docking oriented_structures/COVID19orf9c_Q2PZI1.pdb in 413.96746707
# Finished Docking oriented_structures/COVID19nsp7_Q9NP72.pdb in 680.627943993
# Finished Docking oriented_structures/COVID19nsp10_P55789.pdb in 647.923908949
# Finished Docking oriented_structures/COVID19nsp12_Q70EL1.pdb in 5955.09695005
# Finished Docking oriented_structures/COVID19nsp13_Q9BQQ3.pdb in 3402.35879302
# Finished Docking oriented_structures/COVID19nsp14_Q9NXA8.pdb in 1398.98907089
# Finished Docking oriented_structures/COVID19nsp2_O14975.pdb in 2664.7413919
# Finished Docking oriented_structures/COVID19nsp8_Q13206.pdb in 525.869163036
# Finished Docking oriented_structures/COVID19orf8_Q9P2E5.pdb in 375.440404892
# Finished Docking oriented_structures/COVID19nsp12_Q99081.pdb in 3341.16908407
# Finished Docking oriented_structures/COVID19nsp9_Q99567.pdb in 831.065638065
# Finished Docking oriented_structures/COVID19orf8_Q9BS26.pdb in 569.734989882
# Finished Docking oriented_structures/COVID19nsp12_Q8IWR0.pdb in 3568.38720298
# Finished Docking oriented_structures/COVID19orf8_Q99519.pdb in 1603.75278401
# Finished Docking oriented_structures/COVID19nsp7_P62820.pdb in 218.444929838
# Finished Docking oriented_structures/COVID19orf8_Q8N0Z8.pdb in 486.232522964
# Finished Docking oriented_structures/COVID19orf9c_Q9Y375.pdb in 132.30510807
# Finished Docking oriented_structures/COVID19nsp8_Q9HD40.pdb in 977.765418053
# Finished Docking oriented_structures/COVID19nsp13_Q8N4C6.pdb in 9478.278265
# Finished Docking oriented_structures/COVID19nsp13_Q4V328.pdb in 9030.61704588
# Finished Docking oriented_structures/COVID19nsp13_Q8N3C7.pdb in 2421.88744807
# Finished Docking oriented_structures/COVID19nsp7_Q9H7Z7.pdb in 126.069419861
# Error 1
# cmd: nice python Docking_Script.py --pdb_filename [REDACTED_PATH]Collaborators/Resource_Maintenance/2020_04_27_Guided_Docking_Test/random_docking_inputs/COVID19orf8_Q92820_6.pdb --partners A_B --jobs 1 --job_output COVID19orf8_Q92820_6
# RunTime: 2675.64246202
#
# Finished Docking oriented_structures/COVID19nsp12_Q2T9J0.pdb in 3799.40611792
# Finished Docking oriented_structures/COVID19orf8_Q9H173.pdb in 484.005917072
# Finished Docking oriented_structures/COVID19orf8_Q86YB8.pdb in 783.765570879
# Finished Docking oriented_structures/COVID19nsp9_P37198.pdb in 871.733433008
# Finished Docking oriented_structures/COVID19orf7a_Q9NU22.pdb in 5717.08831596
# Finished Docking oriented_structures/COVID19nsp7_Q5VT66.pdb in 429.796895981
# Finished Docking oriented_structures/COVID19nsp13_Q96N16.pdb in 2803.29333806
# Finished Docking oriented_structures/COVID19nsp7_P61586.pdb in 700.468161821
# Finished Docking oriented_structures/COVID19orf6_P78406.pdb in 465.782727003
# Finished Docking oriented_structures/COVID19nsp9_P13984.pdb in 158.992516041
# Finished Docking oriented_structures/COVID19orf9c_Q6NXT4.pdb in 125.066129923
# Error 1
# cmd: nice python Docking_Script.py --pdb_filename [REDACTED_PATH]Collaborators/Resource_Maintenance/2020_04_27_Guided_Docking_Test/random_docking_inputs/COVID19nsp13_O75506_6.pdb --partners A_B --jobs 1 --job_output COVID19nsp13_O75506_6
# RunTime: 2478.43510818
#
# Finished Docking oriented_structures/COVID19orf8_Q9NXK8.pdb in 561.727128029
# Finished Docking oriented_structures/COVID19nsp8_Q7L2J0.pdb in 452.808976173
# Finished Docking oriented_structures/COVID19orf9c_Q96K12.pdb in 320.127038956
# Finished Docking oriented_structures/COVID19nsp9_Q8TD19.pdb in 283.768026829
# Finished Docking oriented_structures/COVID19Spike_Q9C0B5.pdb in 6655.32147217
# Finished Docking oriented_structures/COVID19orf6_Q9NZJ7.pdb in 280.477129936
# Finished Docking oriented_structures/COVID19orf9c_Q7Z2K6.pdb in 350.656708002
# Finished Docking oriented_structures/COVID19orf9b_P27448.pdb in 1353.10397792
# Finished Docking oriented_structures/COVID19orf8_Q9BZQ6.pdb in 534.162921906
# Finished Docking oriented_structures/COVID19nsp4_P14735.pdb in 8979.14918208
# Finished Docking oriented_structures/COVID19Spike_Q7Z5G4.pdb in 6168.90350986
# Finished Docking oriented_structures/COVID19orf9c_Q9Y6M9.pdb in 258.913378
# Finished Docking oriented_structures/COVID19orf8_Q8IWF2.pdb in 514.824850082
# Finished Docking oriented_structures/COVID19nsp4_Q9BSF4.pdb in 1759.727355
# Finished Docking oriented_structures/COVID19nsp7_P61026.pdb in 691.34198904
# Finished Docking oriented_structures/COVID19orf9b_Q9UL15.pdb in 432.702237844
# Finished Docking oriented_structures/COVID19nsp7_Q8WUY8.pdb in 369.523617029
# Finished Docking oriented_structures/COVID19orf9c_Q86UT6.pdb in 1335.30075908
# Finished Docking oriented_structures/COVID19nsp8_Q9ULT8.pdb in 826.148082972
# Finished Docking oriented_structures/COVID19nsp7_Q13724.pdb in 533.642390013
# Finished Docking oriented_structures/COVID19nsp8_Q13868.pdb in 667.161664963
# Finished Docking oriented_structures/COVID19orf8_Q8IV08.pdb in 196.154549837
# Finished Docking oriented_structures/COVID19orf9c_Q96S52.pdb in 438.006488085
# Finished Docking oriented_structures/COVID19nsp8_P09132.pdb in 993.906169891
# Finished Docking oriented_structures/COVID19orf8_O76061.pdb in 499.854845047
# Finished Docking oriented_structures/COVID19orf8_Q96DZ1.pdb in 566.508715868
# Finished Docking oriented_structures/COVID19orf9c_Q9BQ95.pdb in 563.978526115
# Finished Docking oriented_structures/COVID19nsp12_Q13546.pdb in 4970.27905893
# Finished Docking oriented_structures/COVID19nsp12_Q5EBL8.pdb in 3875.39182401
# Finished Docking oriented_structures/COVID19nsp8_Q9Y399.pdb in 723.003063917
# Finished Docking oriented_structures/COVID19nsp7_O95573.pdb in 124.883627176
# Finished Docking oriented_structures/COVID19nsp12_Q9H2H8.pdb in 3687.40275002
# Finished Docking oriented_structures/COVID19nsp7_Q9BQE4.pdb in 419.420682907
# Finished Docking oriented_structures/COVID19nsp13_P31323.pdb in 1009.85044885
# Finished Docking oriented_structures/COVID19nsp7_P61019.pdb in 215.808012962
# Finished Docking oriented_structures/COVID19nsp9_P61962.pdb in 548.06382823
# Finished Docking oriented_structures/COVID19nsp13_Q9BV73.pdb in 9257.49567485
# Finished Docking oriented_structures/COVID19nsp13_Q92995.pdb in 2601.61531806
# Finished Docking oriented_structures/COVID19nsp13_Q9UHD2.pdb in 1300.10614896
# Finished Docking oriented_structures/COVID19orf9c_Q9GZU3.pdb in 124.047619104
# Finished Docking oriented_structures/COVID19nsp12_Q5VUA4.pdb in 4000.15999889
# Finished Docking oriented_structures/COVID19orf8_P05556.pdb in 409.328941107
# Finished Docking oriented_structures/COVID19nsp7_P63218.pdb in 311.534960032
# Finished Docking oriented_structures/COVID19nsp13_A7MCY6.pdb in 3806.917377
# Finished Docking oriented_structures/COVID19orf8_O14656.pdb in 1244.54103518
# Finished Docking oriented_structures/COVID19nsp1_Q8NBJ5.pdb in 443.81440115
# Finished Docking oriented_structures/COVID19nsp12_O75592.pdb in 5022.15523291
# Finished Docking oriented_structures/COVID19nsp13_Q5VU43.pdb in 8276.73570299
# Finished Docking oriented_structures/COVID19orf8_P61916.pdb in 250.544692993
# Finished Docking oriented_structures/COVID19nsp7_Q12907.pdb in 246.211297035
# Finished Docking oriented_structures/COVID19nsp7_Q5JTV8.pdb in 322.659145832
# Finished Docking oriented_structures/COVID19nsp12_Q6UUV7.pdb in 8762.15880609
# Finished Docking oriented_structures/COVID19nsp2_P52306.pdb in 5365.17305493
# Finished Docking oriented_structures/COVID19orf8_P00750.pdb in 383.371483088
# Finished Docking oriented_structures/COVID19nsp2_P16435.pdb in 3438.68456578
# Finished Docking oriented_structures/COVID19orf8_Q99470.pdb in 299.253103971
# Finished Docking oriented_structures/COVID19orf9b_O75534.pdb in 431.599259138
# Finished Docking oriented_structures/COVID19nsp9_Q86YT6.pdb in 711.492913008
# Finished Docking oriented_structures/COVID19orf9c_Q12770.pdb in 427.553318024
# Finished Docking oriented_structures/COVID19orf8_P58166.pdb in 164.491916895
# Finished Docking oriented_structures/COVID19nsp13_O95684.pdb in 2698.55641222
# Finished Docking oriented_structures/COVID19orf9c_Q8TEQ8.pdb in 134.503173113
# Finished Docking oriented_structures/COVID19nsp13_Q8IUD2.pdb in 5660.35362697
# Finished Docking oriented_structures/COVID19nsp1_Q99959.pdb in 981.979635954
# Finished Docking oriented_structures/COVID19nsp4_Q2TAA5.pdb in 4464.72159314
# Finished Docking oriented_structures/COVID19nsp13_Q7Z7A1.pdb in 2167.41247606
# Error 1
# cmd: nice python Docking_Script.py --pdb_filename [REDACTED_PATH]Collaborators/Resource_Maintenance/2020_04_27_Guided_Docking_Test/random_docking_inputs/COVID19nsp5C145A_P07203_6.pdb --partners A_B --jobs 1 --job_output COVID19nsp5C145A_P07203_6
# RunTime: 2554.39753914
#
# Finished Docking oriented_structures/COVID19nsp13_Q9BV19.pdb in 2513.8760252
# Finished Docking oriented_structures/COVID19nsp13_Q76N32.pdb in 2704.78097606
# Finished Docking oriented_structures/COVID19nsp12_Q14157.pdb in 4178.03924084
# Finished Docking oriented_structures/COVID19orf8_Q96MM7.pdb in 212.433470011
# Finished Docking oriented_structures/COVID19nsp8_O96028.pdb in 1326.87411499
# Finished Docking oriented_structures/COVID19orf8_Q96AY3.pdb in 185.706610918
# Finished Docking oriented_structures/COVID19nsp8_P82663.pdb in 698.904442072
# Finished Docking oriented_structures/COVID19orf9c_Q5BJF2.pdb in 132.773662806
# Finished Docking oriented_structures/COVID19nsp13_Q9BQS8.pdb in 2132.05674696
# Finished Docking oriented_structures/COVID19nsp12_O43823.pdb in 4190.77017403
# Finished Docking oriented_structures/COVID19nsp8_O76094.pdb in 1129.510674
# Finished Docking oriented_structures/COVID19nsp12_O95391.pdb in 5692.07296896
# Error 1
# cmd: nice python Docking_Script.py --pdb_filename [REDACTED_PATH]Collaborators/Resource_Maintenance/2020_04_27_Guided_Docking_Test/random_docking_inputs/COVID19orf8_P28300_6.pdb --partners A_B --jobs 1 --job_output COVID19orf8_P28300_6
# RunTime: 1029.0797801
#
# Finished Docking oriented_structures/COVID19nsp13_Q8IWJ2.pdb in 1107.79603505
# Finished Docking oriented_structures/COVID19nsp9_Q8N0X7.pdb in 205.281789064
# Finished Docking oriented_structures/COVID19nsp13_Q8TD10.pdb in 2673.87040401
# Finished Docking oriented_structures/COVID19nsp8_Q8NEJ9.pdb in 925.201170921
# Finished Docking oriented_structures/COVID19orf9c_Q9BVK2.pdb in 324.364694118
# Finished Docking oriented_structures/COVID19nsp8_P82675.pdb in 217.599882126
# Finished Docking oriented_structures/COVID19nsp14_P12268.pdb in 1600.48791885
# Finished Docking oriented_structures/COVID19nsp7_P11233.pdb in 569.417714834
# Finished Docking oriented_structures/COVID19orf9b_Q7KZI7.pdb in 1435.30324817
# Finished Docking oriented_structures/COVID19nsp7_P21964.pdb in 296.032234192
#
# Docking Iteration 7
# HBox(children=(IntProgress(value=0, max=250), HTML(value=u'')))
# Finished Docking oriented_structures/COVID19nsp7_P62873.pdb in 485.544555187
# Finished Docking oriented_structures/COVID19nsp10_Q969X5.pdb in 565.657472849
# Finished Docking oriented_structures/COVID19nsp7_Q8N183.pdb in 431.809425116
# Finished Docking oriented_structures/COVID19orf9b_O14745.pdb in 525.574223042
# Finished Docking oriented_structures/COVID19orf9b_Q9P0L2.pdb in 523.635840178
# Finished Docking oriented_structures/COVID19nsp7_Q8NBX0.pdb in 476.310188055
# Finished Docking oriented_structures/COVID19nsp15_P61970.pdb in 1838.57658887
# Finished Docking oriented_structures/COVID19nsp7_Q96A26.pdb in 506.307767868
# Finished Docking oriented_structures/COVID19orf9c_Q9H845.pdb in 1154.38309979
# Finished Docking oriented_structures/COVID19orf9c_Q9H3K2.pdb in 386.923538923
# Finished Docking oriented_structures/COVID19nsp13_O14578.pdb in 7166.00784707
# Error 1
# cmd: nice python Docking_Script.py --pdb_filename [REDACTED_PATH]Collaborators/Resource_Maintenance/2020_04_27_Guided_Docking_Test/random_docking_inputs/COVID19orf8_Q96IV0_6.pdb --partners A_B --jobs 1 --job_output COVID19orf8_Q96IV0_6
# RunTime: 1125.9045732
#
# Finished Docking oriented_structures/COVID19orf9b_Q9H2P9.pdb in 1093.84266901
# Finished Docking oriented_structures/COVID19orf8_Q96F46.pdb in 1091.76143503
# Finished Docking oriented_structures/COVID19nsp13_Q04724.pdb in 3992.45994186
# Finished Docking oriented_structures/COVID19nsp1_P09884.pdb in 370.281585932
# Finished Docking oriented_structures/COVID19orf8_Q13438.pdb in 265.608681917
# Finished Docking oriented_structures/COVID19nsp9_P35556.pdb in 564.761622906
# Finished Docking oriented_structures/COVID19nsp9_Q96F45.pdb in 683.74138093
# Finished Docking oriented_structures/COVID19nsp13_Q8N8E3.pdb in 4329.36619997
# Finished Docking oriented_structures/COVID19nsp13_P35241.pdb in 2779.65522504
# Finished Docking oriented_structures/COVID19orf9b_Q9UKA9.pdb in 216.100940943
# Finished Docking oriented_structures/COVID19nsp12_Q5T6F2.pdb in 4389.17303705
# Finished Docking oriented_structures/COVID19nsp2_Q6Y7W6.pdb in 2571.3181231
# Finished Docking oriented_structures/COVID19orf8_O00469.pdb in 746.301822186
# Finished Docking oriented_structures/COVID19nsp7_P61006.pdb in 564.033174038
# Finished Docking oriented_structures/COVID19orf8_Q7Z4H8.pdb in 168.277766228
# Finished Docking oriented_structures/COVID19orf7a_Q7Z4Q2.pdb in 190.592303991
# Finished Docking oriented_structures/COVID19orf8_Q9BRN9.pdb in 571.941475153
# Finished Docking oriented_structures/COVID19nsp9_Q9NZL9.pdb in 1256.73200297
# Finished Docking oriented_structures/COVID19nsp7_O00116.pdb in 1423.45228696
# Finished Docking oriented_structures/COVID19nsp8_Q4G0J3.pdb in 1228.96217704
# Finished Docking oriented_structures/COVID19nsp9_Q7Z3B4.pdb in 379.617047787
# Finished Docking oriented_structures/COVID19nsp12_Q96IZ5.pdb in 1920.29414606
# Finished Docking oriented_structures/COVID19orf8_Q9H488.pdb in 631.384999037
# Finished Docking oriented_structures/COVID19nsp8_Q96I59.pdb in 741.905870199
# Finished Docking oriented_structures/COVID19nsp9_Q9UBX5.pdb in 416.429425955
# Finished Docking oriented_structures/COVID19orf8_P12109.pdb in 173.660312176
# Finished Docking oriented_structures/COVID19nsp13_Q9UJC3.pdb in 7859.14550114
# Finished Docking oriented_structures/COVID19orf8_Q99988.pdb in 212.694761992
# Finished Docking oriented_structures/COVID19nsp4_Q9NVH1.pdb in 2616.67417502
# Finished Docking oriented_structures/COVID19orf9c_O76024.pdb in 429.352199078
# Finished Docking oriented_structures/COVID19orf9c_Q9NV92.pdb in 124.689564943
# Finished Docking oriented_structures/COVID19nsp15_P62330.pdb in 2193.99354887
# Finished Docking oriented_structures/COVID19nsp8_Q9H6F5.pdb in 673.306304932
# Finished Docking oriented_structures/COVID19nsp5_Q92769.pdb in 3105.45217586
# Finished Docking oriented_structures/COVID19nsp13_O95613.pdb in 5486.25511909
# Finished Docking oriented_structures/COVID19nsp4_Q9Y5J6.pdb in 2453.74299097
# Finished Docking oriented_structures/COVID19orf8_Q8IZ52.pdb in 496.020836115
# Finished Docking oriented_structures/COVID19nsp9_Q9BVL2.pdb in 503.505630016
# Finished Docking oriented_structures/COVID19orf8_Q15818.pdb in 536.804369926
# Finished Docking oriented_structures/COVID19nsp14_P06280.pdb in 4822.29444289
# Error 1
# cmd: nice python Docking_Script.py --pdb_filename [REDACTED_PATH]Collaborators/Resource_Maintenance/2020_04_27_Guided_Docking_Test/random_docking_inputs/COVID19nsp15_Q9H4P4_7.pdb --partners A_B --jobs 1 --job_output COVID19nsp15_Q9H4P4_7
# RunTime: 2140.54092503
#
# Finished Docking oriented_structures/COVID19nsp12_Q5JSZ5.pdb in 11313.582505
# Finished Docking oriented_structures/COVID19nsp13_Q96CN9.pdb in 2948.94885087
# Finished Docking oriented_structures/COVID19nsp7_P51148.pdb in 583.257102013
# Finished Docking oriented_structures/COVID19nsp1_Q14181.pdb in 426.552037001
# Finished Docking oriented_structures/COVID19nsp13_P13861.pdb in 2728.85635304
# Finished Docking oriented_structures/COVID19nsp2_Q2M389.pdb in 9309.24607706
# Finished Docking oriented_structures/COVID19nsp1_P49642.pdb in 1657.50768495
# Finished Docking oriented_structures/COVID19nsp7_O43169.pdb in 161.125011206
# Finished Docking oriented_structures/COVID19nsp10_Q96CW1.pdb in 1104.45397305
# Finished Docking oriented_structures/COVID19nsp7_Q8WVC6.pdb in 795.498209
# Finished Docking oriented_structures/COVID19orf8_Q6UW63.pdb in 605.889701843
# Finished Docking oriented_structures/COVID19nsp4_Q9Y5J7.pdb in 881.193778992
# Finished Docking oriented_structures/COVID19nsp8_Q92552.pdb in 480.995123148
# Finished Docking oriented_structures/COVID19nsp12_Q92615.pdb in 3290.42084694
# Finished Docking oriented_structures/COVID19nsp12_Q9HAU0.pdb in 4676.39491391
# Finished Docking oriented_structures/COVID19orf8_Q9NYU1.pdb in 2662.72354317
# Finished Docking oriented_structures/COVID19nsp9_P35658.pdb in 1919.76848602
# Finished Docking oriented_structures/COVID19orf9c_Q86VR2.pdb in 428.847476959
# Finished Docking oriented_structures/COVID19nsp13_Q14789.pdb in 6020.56837797
# Finished Docking oriented_structures/COVID19nsp7_Q7LGA3.pdb in 1298.32851195
# Finished Docking oriented_structures/COVID19nsp7_P51149.pdb in 224.607117891
# Finished Docking oriented_structures/COVID19orf8_P15151.pdb in 366.100013018
# Finished Docking oriented_structures/COVID19orf9c_P55085.pdb in 297.275382042
# Finished Docking oriented_structures/COVID19orf8_P0C7P0.pdb in 570.514256001
# Finished Docking oriented_structures/COVID19nsp7_P61106.pdb in 604.972352982
# Finished Docking oriented_structures/COVID19orf8_P26358.pdb in 1077.71178007
# Finished Docking oriented_structures/COVID19nsp2_O60573.pdb in 3342.33501601
# Finished Docking oriented_structures/COVID19nsp8_O95260.pdb in 1406.54788399
# Finished Docking oriented_structures/COVID19nsp13_Q5VT06.pdb in 2662.62736416
# Finished Docking oriented_structures/COVID19orf8_Q9H4F8.pdb in 193.728735924
# Finished Docking oriented_structures/COVID19nsp13_Q66GS9.pdb in 1063.76058602
# Error 1
# cmd: nice python Docking_Script.py --pdb_filename [REDACTED_PATH]Collaborators/Resource_Maintenance/2020_04_27_Guided_Docking_Test/random_docking_inputs/COVID19nsp7_Q96DA6_7.pdb --partners A_B --jobs 1 --job_output COVID19nsp7_Q96DA6_7
# RunTime: 932.041293144
#
# Finished Docking oriented_structures/COVID19nsp4_Q8TEM1.pdb in 3042.97113299
# Finished Docking oriented_structures/COVID19nsp13_Q08117.pdb in 2320.22198296
# Finished Docking oriented_structures/COVID19nsp13_Q4V328.pdb in 4946.45091701
# Finished Docking oriented_structures/COVID19nsp10_Q9HAV7.pdb in 471.701075077
# Finished Docking oriented_structures/COVID19orf8_Q9H8W4.pdb in 504.939528942
# Finished Docking oriented_structures/COVID19orf9c_Q9Y276.pdb in 382.769685984
# Finished Docking oriented_structures/COVID19orf8_Q13443.pdb in 159.679709196
# Finished Docking oriented_structures/COVID19nsp13_Q8N4C6.pdb in 5501.47870088
# Finished Docking oriented_structures/COVID19orf9c_Q6NXT6.pdb in 165.945906878
# Finished Docking oriented_structures/COVID19nsp13_P17612.pdb in 2026.15683913
# Finished Docking oriented_structures/COVID19nsp9_P35555.pdb in 471.135538101
# Finished Docking oriented_structures/COVID19nsp7_P00387.pdb in 372.753485918
# Finished Docking oriented_structures/COVID19orf9c_O43292.pdb in 2576.2019999
# Finished Docking oriented_structures/COVID19orf9c_O00124.pdb in 443.656225204
# Finished Docking oriented_structures/COVID19orf9b_O43633.pdb in 467.422884941
# Finished Docking oriented_structures/COVID19orf9b_O94826.pdb in 540.409012794
# Finished Docking oriented_structures/COVID19orf8_Q8N766.pdb in 2729.00532389
# Finished Docking oriented_structures/COVID19nsp7_Q8WTV0.pdb in 505.245733023
# Finished Docking oriented_structures/COVID19nsp8_P61011.pdb in 337.264401913
# Finished Docking oriented_structures/COVID19orf8_Q08431.pdb in 405.189374924
# Finished Docking oriented_structures/COVID19nsp9_Q15056.pdb in 163.076268196
# Finished Docking oriented_structures/COVID19nsp12_A3KN83.pdb in 3585.55435801
# Finished Docking oriented_structures/COVID19nsp13_Q04726.pdb in 2159.16247296
# Finished Docking oriented_structures/COVID19nsp1_P49643.pdb in 765.448155165
# Finished Docking oriented_structures/COVID19nsp8_O00566.pdb in 763.240442991
# Finished Docking oriented_structures/COVID19nsp12_O14874.pdb in 7036.14074802
# Finished Docking oriented_structures/COVID19orf9c_Q9Y3A6.pdb in 196.088766098
# Finished Docking oriented_structures/COVID19nsp2_Q5T1M5.pdb in 2883.35040998
# Finished Docking oriented_structures/COVID19nsp12_Q8IWR0.pdb in 1843.46988392
# Finished Docking oriented_structures/COVID19nsp13_Q9Y2I6.pdb in 2676.03594995
# Finished Docking oriented_structures/COVID19orf9b_Q9H773.pdb in 445.165627003
# Finished Docking oriented_structures/COVID19orf8_P29122.pdb in 524.231766939
# Finished Docking oriented_structures/COVID19nsp8_Q9BSC4.pdb in 3575.54457402
# Error 1
# cmd: nice python Docking_Script.py --pdb_filename [REDACTED_PATH]Collaborators/Resource_Maintenance/2020_04_27_Guided_Docking_Test/random_docking_inputs/COVID19orf8_Q9Y4L1_6.pdb --partners A_B --jobs 1 --job_output COVID19orf8_Q9Y4L1_6
# RunTime: 9053.2423389
#
# Finished Docking oriented_structures/COVID19nsp7_Q6ZRP7.pdb in 490.036736965
# Finished Docking oriented_structures/COVID19nsp5C145A_Q9NXH9.pdb in 1410.44178891
# Finished Docking oriented_structures/COVID19nsp8_Q9NY61.pdb in 642.824185133
# Finished Docking oriented_structures/COVID19orf6_P52948.pdb in 188.062596083
# Finished Docking oriented_structures/COVID19orf8_Q92820.pdb in 1444.41851187
# Finished Docking oriented_structures/COVID19nsp7_Q9NP72.pdb in 637.615893841
# Finished Docking oriented_structures/COVID19nsp10_P55789.pdb in 574.83107996
# Finished Docking oriented_structures/COVID19orf8_Q9UHI8.pdb in 521.119023085
# Finished Docking oriented_structures/COVID19orf9c_P33527.pdb in 951.20502305
# Finished Docking oriented_structures/COVID19nsp13_Q9BQQ3.pdb in 3191.10599589
# Finished Docking oriented_structures/COVID19nsp13_O75506.pdb in 1029.70550203
# Finished Docking oriented_structures/COVID19nsp12_Q99081.pdb in 3083.5373981
# Finished Docking oriented_structures/COVID19nsp2_O14975.pdb in 2880.733706
# Finished Docking oriented_structures/COVID19nsp8_Q13206.pdb in 613.508650064
# Error 1
# cmd: nice python Docking_Script.py --pdb_filename [REDACTED_PATH]Collaborators/Resource_Maintenance/2020_04_27_Guided_Docking_Test/random_docking_inputs/COVID19orf9c_Q2PZI1_7.pdb --partners A_B --jobs 1 --job_output COVID19orf9c_Q2PZI1_7
# RunTime: 1073.86386895
#
# Finished Docking oriented_structures/COVID19nsp13_Q96SN8.pdb in 2619.48363996
# Finished Docking oriented_structures/COVID19orf8_Q9P2E5.pdb in 171.685212851
# Finished Docking oriented_structures/COVID19orf8_Q99519.pdb in 1632.51095223
# Finished Docking oriented_structures/COVID19nsp13_Q08378.pdb in 10141.041569
# Finished Docking oriented_structures/COVID19nsp12_Q6UUV7.pdb in 4649.733845
# Error 1
# cmd: nice python Docking_Script.py --pdb_filename [REDACTED_PATH]Collaborators/Resource_Maintenance/2020_04_27_Guided_Docking_Test/random_docking_inputs/COVID19nsp13_Q8N3C7_7.pdb --partners A_B --jobs 1 --job_output COVID19nsp13_Q8N3C7_7
# RunTime: 2582.77039695
#
# Finished Docking oriented_structures/COVID19nsp8_Q9HD40.pdb in 1238.71196604
# Finished Docking oriented_structures/COVID19nsp9_P37198.pdb in 398.082901001
# Finished Docking oriented_structures/COVID19nsp7_P62820.pdb in 805.424043179
# Finished Docking oriented_structures/COVID19orf9c_Q9Y375.pdb in 563.86687398
# Finished Docking oriented_structures/COVID19nsp12_Q2T9J0.pdb in 4156.66945791
# Finished Docking oriented_structures/COVID19Spike_Q9C0B5.pdb in 6042.78849006
# Finished Docking oriented_structures/COVID19nsp7_Q9H7Z7.pdb in 124.47164011
# Finished Docking oriented_structures/COVID19orf7a_Q9NU22.pdb in 5626.45288301
# Finished Docking oriented_structures/COVID19orf8_Q86YB8.pdb in 1066.84770203
# Finished Docking oriented_structures/COVID19nsp13_Q96N16.pdb in 2900.94525123
# Finished Docking oriented_structures/COVID19nsp14_Q9NXA8.pdb in 3037.86965799
# Finished Docking oriented_structures/COVID19orf8_Q9H173.pdb in 722.139266968
# Finished Docking oriented_structures/COVID19nsp7_Q5VT66.pdb in 161.587761879
# Finished Docking oriented_structures/COVID19orf8_Q9BS26.pdb in 1894.69037795
# Finished Docking oriented_structures/COVID19nsp10_O94973.pdb in 5051.39725804
# Finished Docking oriented_structures/COVID19orf8_Q8N0Z8.pdb in 1494.12013912
# Finished Docking oriented_structures/COVID19nsp7_P61586.pdb in 886.029224873
# Finished Docking oriented_structures/COVID19orf8_Q9NXK8.pdb in 501.285859108
# Error 1
# cmd: nice python Docking_Script.py --pdb_filename [REDACTED_PATH]Collaborators/Resource_Maintenance/2020_04_27_Guided_Docking_Test/random_docking_inputs/COVID19Spike_Q7Z5G4_7.pdb --partners A_B --jobs 1 --job_output COVID19Spike_Q7Z5G4_7
# RunTime: 6078.26730299
#
# Finished Docking oriented_structures/COVID19nsp9_Q99567.pdb in 2714.93822908
# Finished Docking oriented_structures/COVID19nsp9_P13984.pdb in 526.879505873
# Finished Docking oriented_structures/COVID19nsp9_Q8TD19.pdb in 275.067464828
# Finished Docking oriented_structures/COVID19orf9c_Q7Z2K6.pdb in 371.144503117
# Finished Docking oriented_structures/COVID19orf9b_P27448.pdb in 1225.50286293
# Error 1
# cmd: nice python Docking_Script.py --pdb_filename [REDACTED_PATH]Collaborators/Resource_Maintenance/2020_04_27_Guided_Docking_Test/random_docking_inputs/COVID19orf9c_Q96K12_7.pdb --partners A_B --jobs 1 --job_output COVID19orf9c_Q96K12_7
# RunTime: 688.366216183
#
# Finished Docking oriented_structures/COVID19orf8_Q9BZQ6.pdb in 557.558488131
# Finished Docking oriented_structures/COVID19orf6_Q9NZJ7.pdb in 315.040133953
# Finished Docking oriented_structures/COVID19orf9c_Q86UT6.pdb in 1036.21861386
# Finished Docking oriented_structures/COVID19nsp7_P61026.pdb in 254.703361034
# Error 1
# cmd: nice python Docking_Script.py --pdb_filename [REDACTED_PATH]Collaborators/Resource_Maintenance/2020_04_27_Guided_Docking_Test/random_docking_inputs/COVID19orf9c_Q6NXT4_7.pdb --partners A_B --jobs 1 --job_output COVID19orf9c_Q6NXT4_7
# RunTime: 1044.39114404
#
# Finished Docking oriented_structures/COVID19nsp4_P14735.pdb in 9197.50207496
# Finished Docking oriented_structures/COVID19orf9c_Q9Y6M9.pdb in 236.478204966
# Finished Docking oriented_structures/COVID19orf8_Q8IWF2.pdb in 489.86993885
# Finished Docking oriented_structures/COVID19nsp8_Q7L2J0.pdb in 1527.26163507
# ...
# Finished Docking oriented_structures/COVID19nsp12_Q9H2H8.pdb in 2024.37265992
# Finished Docking oriented_structures/COVID19orf8_Q8IWF2.pdb in 450.198848009
# Finished Docking oriented_structures/COVID19orf9c_Q9Y6M9.pdb in 236.449244976
# Finished Docking oriented_structures/COVID19orf8_Q9BZQ6.pdb in 556.74856782
# Finished Docking oriented_structures/COVID19nsp7_Q13724.pdb in 129.613402843
# Error 1
# cmd: nice python Docking_Script.py --pdb_filename [REDACTED_PATH]Collaborators/Resource_Maintenance/2020_04_27_Guided_Docking_Test/random_docking_inputs/COVID19nsp9_P13984_9.pdb --partners A_B --jobs 1 --job_output COVID19nsp9_P13984_9
# RunTime: 878.663296938
#
# Finished Docking oriented_structures/COVID19orf8_Q8IV08.pdb in 157.158727884
# Finished Docking oriented_structures/COVID19orf9c_Q96S52.pdb in 92.5170199871
# Finished Docking oriented_structures/COVID19nsp12_Q5VUA4.pdb in 1902.95752406
# Finished Docking oriented_structures/COVID19nsp8_Q13868.pdb in 545.171426058
# Finished Docking oriented_structures/COVID19nsp7_Q8WUY8.pdb in 316.462033033
# Finished Docking oriented_structures/COVID19orf9c_Q86UT6.pdb in 1137.00691414
# Finished Docking oriented_structures/COVID19nsp8_Q9ULT8.pdb in 718.094274998
# Finished Docking oriented_structures/COVID19orf9b_Q9UL15.pdb in 457.268754005
# Finished Docking oriented_structures/COVID19orf9c_Q9BQ95.pdb in 135.777472973
# Finished Docking oriented_structures/COVID19nsp7_Q9BQE4.pdb in 124.880068064
# Finished Docking oriented_structures/COVID19nsp4_Q9BSF4.pdb in 1922.26120305
# Finished Docking oriented_structures/COVID19orf8_O76061.pdb in 424.123075008
# Finished Docking oriented_structures/COVID19orf8_Q96DZ1.pdb in 578.759721041
# Finished Docking oriented_structures/COVID19nsp7_O95573.pdb in 120.118443966
# Finished Docking oriented_structures/COVID19nsp2_P16435.pdb in 1507.2505219
# Finished Docking oriented_structures/COVID19nsp8_Q9Y399.pdb in 671.228215933
# Finished Docking oriented_structures/COVID19orf8_O14656.pdb in 451.985252142
# Finished Docking oriented_structures/COVID19nsp12_O95391.pdb in 2451.58350492
# Finished Docking oriented_structures/COVID19nsp13_O95684.pdb in 1127.14312601
# Finished Docking oriented_structures/COVID19nsp9_P61962.pdb in 483.928174973
# Finished Docking oriented_structures/COVID19nsp13_A7MCY6.pdb in 2609.39453292
# Error 1
# cmd: nice python Docking_Script.py --pdb_filename [REDACTED_PATH]Collaborators/Resource_Maintenance/2020_04_27_Guided_Docking_Test/random_docking_inputs/COVID19orf8_Q8N766_9.pdb --partners A_B --jobs 1 --job_output COVID19orf8_Q8N766_9
# RunTime: 8931.36863112
#
# Finished Docking oriented_structures/COVID19nsp12_Q5EBL8.pdb in 3946.76554084
# Error 1
# cmd: nice python Docking_Script.py --pdb_filename [REDACTED_PATH]Collaborators/Resource_Maintenance/2020_04_27_Guided_Docking_Test/random_docking_inputs/COVID19nsp8_Q7L2J0_9.pdb --partners A_B --jobs 1 --job_output COVID19nsp8_Q7L2J0_9
# RunTime: 2272.60814095
#
# Finished Docking oriented_structures/COVID19nsp13_P31323.pdb in 973.512089014
# Error 1
# cmd: nice python Docking_Script.py --pdb_filename [REDACTED_PATH]Collaborators/Resource_Maintenance/2020_04_27_Guided_Docking_Test/random_docking_inputs/COVID19nsp8_P09132_9.pdb --partners A_B --jobs 1 --job_output COVID19nsp8_P09132_9
# RunTime: 1464.62049007
#
# Finished Docking oriented_structures/COVID19orf8_P05556.pdb in 139.41899991
# Finished Docking oriented_structures/COVID19nsp13_Q9UHD2.pdb in 1145.83606911
# Finished Docking oriented_structures/COVID19orf9c_Q9GZU3.pdb in 301.004979849
# Finished Docking oriented_structures/COVID19nsp7_P61019.pdb in 556.325737
# Finished Docking oriented_structures/COVID19nsp13_Q76N32.pdb in 1167.51325488
# Finished Docking oriented_structures/COVID19nsp7_P63218.pdb in 325.757970095
# Finished Docking oriented_structures/COVID19nsp1_Q8NBJ5.pdb in 397.666380167
# Finished Docking oriented_structures/COVID19orf8_P61916.pdb in 224.969974995
# Finished Docking oriented_structures/COVID19nsp1_Q99959.pdb in 379.96718502
# Finished Docking oriented_structures/COVID19nsp13_Q9BV73.pdb in 9478.50722909
# Finished Docking oriented_structures/COVID19orf9c_Q12770.pdb in 165.463308811
# Finished Docking oriented_structures/COVID19nsp5C145A_P07203.pdb in 1598.20325089
# Finished Docking oriented_structures/COVID19nsp7_Q12907.pdb in 303.618893862
# Finished Docking oriented_structures/COVID19nsp13_Q92995.pdb in 2804.71019697
# Finished Docking oriented_structures/COVID19orf8_Q99470.pdb in 299.900258064
# Finished Docking oriented_structures/COVID19orf9b_O75534.pdb in 494.630801916
# Finished Docking oriented_structures/COVID19nsp9_Q86YT6.pdb in 656.850775957
# Finished Docking oriented_structures/COVID19nsp7_Q5JTV8.pdb in 820.064388037
# Error 1
# cmd: nice python Docking_Script.py --pdb_filename [REDACTED_PATH]Collaborators/Resource_Maintenance/2020_04_27_Guided_Docking_Test/random_docking_inputs/COVID19nsp12_Q70EL1_9.pdb --partners A_B --jobs 1 --job_output COVID19nsp12_Q70EL1_9
# RunTime: 11086.629272
#
# Finished Docking oriented_structures/COVID19orf8_P58166.pdb in 507.850955963
# Finished Docking oriented_structures/COVID19orf9c_Q8TEQ8.pdb in 412.204395056
# Finished Docking oriented_structures/COVID19orf8_P00750.pdb in 1092.97914195
# Finished Docking oriented_structures/COVID19nsp12_O75592.pdb in 5430.44284487
# Finished Docking oriented_structures/COVID19nsp2_P52306.pdb in 5489.02008104
# Finished Docking oriented_structures/COVID19nsp8_O96028.pdb in 1344.31809402
# Finished Docking oriented_structures/COVID19orf8_P28300.pdb in 538.18795085
# Finished Docking oriented_structures/COVID19nsp13_Q9BV19.pdb in 2460.06749797
# Finished Docking oriented_structures/COVID19nsp8_O76094.pdb in 985.401293993
# Finished Docking oriented_structures/COVID19nsp8_Q8NEJ9.pdb in 252.414726019
# Finished Docking oriented_structures/COVID19nsp13_Q8IWJ2.pdb in 1013.98719192
# Finished Docking oriented_structures/COVID19orf8_Q96AY3.pdb in 191.241381884
# Finished Docking oriented_structures/COVID19orf9b_Q7KZI7.pdb in 1138.78666806
# Finished Docking oriented_structures/COVID19nsp7_P11233.pdb in 223.614276171
# Finished Docking oriented_structures/COVID19nsp13_Q7Z7A1.pdb in 2505.32981896
# Finished Docking oriented_structures/COVID19nsp8_P82663.pdb in 678.528805017
# Finished Docking oriented_structures/COVID19nsp13_Q9BQS8.pdb in 2199.34698296
# Finished Docking oriented_structures/COVID19nsp9_Q8N0X7.pdb in 196.415148973
# Finished Docking oriented_structures/COVID19nsp13_Q8TD10.pdb in 2396.04871893
# Finished Docking oriented_structures/COVID19orf8_Q96IV0.pdb in 198.144116879
# Finished Docking oriented_structures/COVID19nsp12_Q14157.pdb in 3924.45461607
# Finished Docking oriented_structures/COVID19orf9c_Q5BJF2.pdb in 426.152817965
# Finished Docking oriented_structures/COVID19orf8_Q96MM7.pdb in 589.042069912
# Finished Docking oriented_structures/COVID19nsp10_Q969X5.pdb in 198.745476961
# Finished Docking oriented_structures/COVID19orf9c_Q9BVK2.pdb in 359.119542122
# Finished Docking oriented_structures/COVID19nsp8_P82675.pdb in 230.257292986
# Finished Docking oriented_structures/COVID19nsp7_P21964.pdb in 291.369584084
# Finished Docking oriented_structures/COVID19nsp7_Q8N183.pdb in 444.664635897
#
# Docking Iteration 10
# HBox(children=(IntProgress(value=0, max=250), HTML(value=u'')))
# Finished Docking oriented_structures/COVID19nsp7_P62873.pdb in 514.566546917
# Finished Docking oriented_structures/COVID19orf9b_O14745.pdb in 476.781852961
# Finished Docking oriented_structures/COVID19orf9b_Q9P0L2.pdb in 454.17978096
# Finished Docking oriented_structures/COVID19nsp15_P61970.pdb in 1646.76872993
# Finished Docking oriented_structures/COVID19nsp2_Q6Y7W6.pdb in 1210.53835917
# Finished Docking oriented_structures/COVID19orf9c_Q9H3K2.pdb in 128.697988987
# Finished Docking oriented_structures/COVID19nsp7_Q8NBX0.pdb in 356.964604855
# Finished Docking oriented_structures/COVID19orf9b_Q9H2P9.pdb in 1034.64205694
# Finished Docking oriented_structures/COVID19nsp1_P09884.pdb in 122.248862982
# Finished Docking oriented_structures/COVID19nsp7_Q96A26.pdb in 461.676167011
# Error 1
# cmd: nice python Docking_Script.py --pdb_filename [REDACTED_PATH]Collaborators/Resource_Maintenance/2020_04_27_Guided_Docking_Test/random_docking_inputs/COVID19nsp4_Q2TAA5_9.pdb --partners A_B --jobs 1 --job_output COVID19nsp4_Q2TAA5_9
# RunTime: 5785.26404405
#
# Finished Docking oriented_structures/COVID19nsp9_Q96F45.pdb in 139.411427021
# Finished Docking oriented_structures/COVID19orf8_Q96F46.pdb in 1144.05308199
# Finished Docking oriented_structures/COVID19nsp12_Q5T6F2.pdb in 3760.82420015
# Finished Docking oriented_structures/COVID19nsp9_P35556.pdb in 516.242453098
# Finished Docking oriented_structures/COVID19orf8_Q13438.pdb in 196.912726164
# Finished Docking oriented_structures/COVID19nsp13_P35241.pdb in 2676.72215295
# Finished Docking oriented_structures/COVID19nsp13_O14578.pdb in 6866.26430082
# Finished Docking oriented_structures/COVID19orf8_O00469.pdb in 193.042267084
# Finished Docking oriented_structures/COVID19nsp14_P12268.pdb in 3167.56623888
# Finished Docking oriented_structures/COVID19nsp13_Q04724.pdb in 4285.49995804
# Finished Docking oriented_structures/COVID19orf8_Q9BRN9.pdb in 180.197935104
# Finished Docking oriented_structures/COVID19orf9b_Q9UKA9.pdb in 426.489968061
# Finished Docking oriented_structures/COVID19orf9c_Q9H845.pdb in 2497.46736789
# Finished Docking oriented_structures/COVID19nsp7_P61006.pdb in 641.339138985
# Finished Docking oriented_structures/COVID19nsp13_Q96CN9.pdb in 1168.23159194
# Finished Docking oriented_structures/COVID19nsp8_Q4G0J3.pdb in 958.299566031
# Finished Docking oriented_structures/COVID19orf8_Q7Z4H8.pdb in 439.365943909
# Finished Docking oriented_structures/COVID19nsp4_Q9NVH1.pdb in 2288.19091702
# Finished Docking oriented_structures/COVID19nsp9_Q9NZL9.pdb in 1436.76926899
# Finished Docking oriented_structures/COVID19nsp15_P62330.pdb in 1801.56209612
# Finished Docking oriented_structures/COVID19nsp8_Q96I59.pdb in 729.520349979
# Finished Docking oriented_structures/COVID19orf7a_Q7Z4Q2.pdb in 628.342833996
# Finished Docking oriented_structures/COVID19nsp14_P06280.pdb in 4029.13336205
# Finished Docking oriented_structures/COVID19nsp9_Q9UBX5.pdb in 199.805179119
# Finished Docking oriented_structures/COVID19nsp13_Q9UJC3.pdb in 7451.419873
# Finished Docking oriented_structures/COVID19nsp4_Q9Y5J6.pdb in 1864.46942496
# Finished Docking oriented_structures/COVID19nsp9_Q7Z3B4.pdb in 401.472946167
# Finished Docking oriented_structures/COVID19orf8_Q9Y4L1.pdb in 4740.98137498
# Finished Docking oriented_structures/COVID19orf9c_O76024.pdb in 141.967298031
# Finished Docking oriented_structures/COVID19nsp15_Q9H4P4.pdb in 1409.8196311
# Finished Docking oriented_structures/COVID19nsp7_O00116.pdb in 2253.46873403
# Finished Docking oriented_structures/COVID19orf8_P12109.pdb in 459.927386045
# Finished Docking oriented_structures/COVID19orf9c_Q9NV92.pdb in 124.68384409
# Finished Docking oriented_structures/COVID19nsp12_O43823.pdb in 7285.25282502
# Finished Docking oriented_structures/COVID19orf8_Q8IZ52.pdb in 158.69355917
# Finished Docking oriented_structures/COVID19nsp9_Q9BVL2.pdb in 156.454424858
# Finished Docking oriented_structures/COVID19nsp13_Q8IUD2.pdb in 9659.11822796
# Finished Docking oriented_structures/COVID19nsp13_P13861.pdb in 2255.26861596
# Finished Docking oriented_structures/COVID19orf8_Q99988.pdb in 653.033010006
# Finished Docking oriented_structures/COVID19orf8_Q15818.pdb in 200.622309923
# Finished Docking oriented_structures/COVID19nsp13_Q14789.pdb in 5467.39172697
# Finished Docking oriented_structures/COVID19nsp8_Q9H6F5.pdb in 819.916043997
# Finished Docking oriented_structures/COVID19orf8_Q9H488.pdb in 1460.60914707
# Finished Docking oriented_structures/COVID19nsp12_Q9HAU0.pdb in 4242.5687809
# Finished Docking oriented_structures/COVID19nsp7_Q7LGA3.pdb in 518.54789114
# Finished Docking oriented_structures/COVID19nsp1_Q14181.pdb in 528.60025692
# Finished Docking oriented_structures/COVID19nsp7_P51148.pdb in 659.09040308
# Error 1
# cmd: nice python Docking_Script.py --pdb_filename [REDACTED_PATH]Collaborators/Resource_Maintenance/2020_04_27_Guided_Docking_Test/random_docking_inputs/COVID19nsp5_Q92769_9.pdb --partners A_B --jobs 1 --job_output COVID19nsp5_Q92769_9
# RunTime: 4042.18947005
#
# Finished Docking oriented_structures/COVID19orf8_Q6UW63.pdb in 608.753369093
# Finished Docking oriented_structures/COVID19nsp10_Q96CW1.pdb in 1005.62445903
# Finished Docking oriented_structures/COVID19nsp7_Q8WVC6.pdb in 873.113972902
# Finished Docking oriented_structures/COVID19nsp12_Q92615.pdb in 3237.61019897
# Finished Docking oriented_structures/COVID19nsp12_Q96IZ5.pdb in 3922.22742987
# Finished Docking oriented_structures/COVID19nsp13_Q08378.pdb in 5417.65077996
# Finished Docking oriented_structures/COVID19nsp1_P49642.pdb in 1709.50619102
# Finished Docking oriented_structures/COVID19nsp7_O43169.pdb in 404.212722778
# Finished Docking oriented_structures/COVID19nsp9_P35658.pdb in 1878.70729995
# Finished Docking oriented_structures/COVID19nsp8_Q92552.pdb in 528.722370148
# Finished Docking oriented_structures/COVID19orf9c_Q86VR2.pdb in 421.812379837
# Finished Docking oriented_structures/COVID19orf9c_O43292.pdb in 1108.29428911
# Finished Docking oriented_structures/COVID19orf8_P0C7P0.pdb in 477.242685795
# Finished Docking oriented_structures/COVID19nsp13_Q8N8E3.pdb in 7817.70953107
# Finished Docking oriented_structures/COVID19orf9c_P55085.pdb in 127.766081095
# Finished Docking oriented_structures/COVID19nsp13_Q4V328.pdb in 4430.81980014
# Finished Docking oriented_structures/COVID19nsp7_Q96DA6.pdb in 370.045284986
# Finished Docking oriented_structures/COVID19orf8_P26358.pdb in 1024.87820101
# Finished Docking oriented_structures/COVID19orf8_P15151.pdb in 882.029774189
# Finished Docking oriented_structures/COVID19nsp7_P51149.pdb in 599.84807992
# Finished Docking oriented_structures/COVID19nsp8_O95260.pdb in 1465.27025414
# Error 1
# cmd: nice python Docking_Script.py --pdb_filename [REDACTED_PATH]Collaborators/Resource_Maintenance/2020_04_27_Guided_Docking_Test/random_docking_inputs/COVID19nsp2_Q2M389_9.pdb --partners A_B --jobs 1 --job_output COVID19nsp2_Q2M389_9
# RunTime: 10450.8942659
#
# Finished Docking oriented_structures/COVID19nsp13_Q5VT06.pdb in 2652.76817083
# Finished Docking oriented_structures/COVID19nsp12_O14874.pdb in 5587.75337291
# Finished Docking oriented_structures/COVID19nsp4_Q9Y5J7.pdb in 2053.50666213
# Finished Docking oriented_structures/COVID19nsp13_Q08117.pdb in 2218.06493592
# Finished Docking oriented_structures/COVID19nsp7_P61106.pdb in 657.976798058
# Finished Docking oriented_structures/COVID19nsp2_O60573.pdb in 3490.73975801
# Finished Docking oriented_structures/COVID19nsp10_Q9HAV7.pdb in 167.537815094
# Finished Docking oriented_structures/COVID19nsp4_Q8TEM1.pdb in 2897.47311187
# Finished Docking oriented_structures/COVID19orf8_Q13443.pdb in 154.133394957
# Error 1
# cmd: nice python Docking_Script.py --pdb_filename [REDACTED_PATH]Collaborators/Resource_Maintenance/2020_04_27_Guided_Docking_Test/random_docking_inputs/COVID19nsp12_Q5JSZ5_9.pdb --partners A_B --jobs 1 --job_output COVID19nsp12_Q5JSZ5_9
# RunTime: 13119.0416579
#
# Finished Docking oriented_structures/COVID19orf8_Q9H4F8.pdb in 550.026865959
# Finished Docking oriented_structures/COVID19orf9c_Q6NXT6.pdb in 220.033821821
# Finished Docking oriented_structures/COVID19orf8_Q9H8W4.pdb in 573.088658094
# Finished Docking oriented_structures/COVID19orf9b_O94826.pdb in 153.884530067
# Finished Docking oriented_structures/COVID19nsp9_P35555.pdb in 471.319457054
# Finished Docking oriented_structures/COVID19nsp13_P17612.pdb in 1999.05853319
# Finished Docking oriented_structures/COVID19nsp13_O95613.pdb in 8995.71831512
# Error 1
# cmd: nice python Docking_Script.py --pdb_filename [REDACTED_PATH]Collaborators/Resource_Maintenance/2020_04_27_Guided_Docking_Test/random_docking_inputs/COVID19orf9c_Q9Y276_10.pdb --partners A_B --jobs 1 --job_output COVID19orf9c_Q9Y276_10
# RunTime: 888.666384935
#
# Finished Docking oriented_structures/COVID19orf8_Q9NYU1.pdb in 4655.23952794
# Finished Docking oriented_structures/COVID19orf9b_O43633.pdb in 406.809316158
# Finished Docking oriented_structures/COVID19nsp7_Q8WTV0.pdb in 376.599058151

# %%
input_pdbs
# Out:
# ['oriented_structures/COVID19nsp7_Q96A26.pdb',
#  'oriented_structures/COVID19nsp9_Q7Z3B4.clean.pdb',
#  'oriented_structures/COVID19nsp13_Q8N4C6.pdb',
#  'oriented_structures/COVID19orf9c_Q9H3K2.pdb',
#  'oriented_structures/COVID19nsp12_Q96IZ5.pdb',
#  'oriented_structures/COVID19nsp9_P35556.pdb',
#  'oriented_structures/COVID19nsp1_P09884.pdb',
#  'oriented_structures/COVID19nsp4_Q9Y5J6.clean.pdb',
#  'oriented_structures/COVID19nsp9_Q96F45.pdb',
#  'oriented_structures/COVID19nsp15_P62330.pdb',
#  'oriented_structures/COVID19nsp13_Q4V328.pdb',
#  'oriented_structures/COVID19nsp13_Q96CN9.pdb',
#  'oriented_structures/COVID19orf8_Q13438.pdb',
#  'oriented_structures/COVID19nsp4_Q9Y5J6.pdb',
#  'oriented_structures/COVID19nsp7_O00116.pdb',
#  'oriented_structures/COVID19nsp9_Q9NZL9.pdb',
#  'oriented_structures/COVID19nsp7_Q7LGA3.clean.pdb',
#  'oriented_structures/COVID19orf8_O00469.pdb',
#  'oriented_structures/COVID19nsp10_Q96CW1.clean.pdb',
#  'oriented_structures/COVID19nsp12_Q92615.pdb',
#  'oriented_structures/COVID19nsp13_P13861.pdb',
#  'oriented_structures/COVID19nsp8_Q4G0J3.pdb',
#  'oriented_structures/COVID19nsp1_P09884.clean.pdb',
#  'oriented_structures/COVID19nsp7_P61006.pdb',
#  'oriented_structures/COVID19orf9b_Q9UKA9.pdb',
#  'oriented_structures/COVID19nsp9_P35658.clean.pdb',
#  'oriented_structures/COVID19orf8_Q9BRN9.pdb',
#  'oriented_structures/COVID19nsp15_Q9H4P4.pdb',
#  'oriented_structures/COVID19orf8_Q7Z4H8.pdb',
#  'oriented_structures/COVID19nsp8_Q96I59.pdb',
#  'oriented_structures/COVID19orf8_Q9NYU1.pdb',
#  'oriented_structures/COVID19orf7a_Q7Z4Q2.pdb',
#  'oriented_structures/COVID19nsp9_Q7Z3B4.clean.clean.pdb',
#  'oriented_structures/COVID19orf8_Q9H488.pdb',
#  'oriented_structures/COVID19nsp2_O60573.pdb',
#  'oriented_structures/COVID19nsp9_Q7Z3B4.pdb',
#  'oriented_structures/COVID19nsp13_Q5VT06.clean.pdb',
#  'oriented_structures/COVID19nsp9_Q9UBX5.pdb',
#  'oriented_structures/COVID19nsp4_P14735.pdb',
#  'oriented_structures/COVID19nsp1_P49642.pdb',
#  'oriented_structures/COVID19orf8_P12109.pdb',
#  'oriented_structures/COVID19orf9c_O76024.pdb',
#  'oriented_structures/COVID19orf8_Q99988.pdb',
#  'oriented_structures/COVID19nsp8_Q9H6F5.pdb',
#  'oriented_structures/COVID19nsp9_P35556.clean.pdb',
#  'oriented_structures/COVID19nsp12_Q70EL1.pdb',
#  'oriented_structures/COVID19nsp9_P35658.pdb',
#  'oriented_structures/COVID19nsp4_Q8TEM1.pdb',
#  'oriented_structures/COVID19nsp10_Q96CW1.clean.clean.pdb',
#  'oriented_structures/COVID19nsp13_Q5VT06.pdb',
#  'oriented_structures/COVID19orf9c_Q9NV92.pdb',
#  'oriented_structures/COVID19orf8_Q8IZ52.pdb',
#  'oriented_structures/COVID19nsp9_Q9NZL9.clean.pdb',
#  'oriented_structures/COVID19nsp9_Q9BVL2.pdb',
#  'oriented_structures/COVID19orf9c_Q9NV92.clean.pdb',
#  'oriented_structures/COVID19orf8_Q15818.pdb',
#  'oriented_structures/COVID19nsp7_P51148.clean.pdb',
#  'oriented_structures/COVID19nsp10_Q96CW1.pdb',
#  'oriented_structures/COVID19nsp7_P51148.pdb',
#  'oriented_structures/COVID19nsp7_Q7LGA3.pdb',
#  'oriented_structures/COVID19nsp1_Q14181.pdb',
#  'oriented_structures/COVID19nsp7_Q8WVC6.pdb',
#  'oriented_structures/COVID19nsp13_Q08117.pdb',
#  'oriented_structures/COVID19nsp12_A3KN83.pdb',
#  'oriented_structures/COVID19nsp4_Q9Y5J7.pdb',
#  'oriented_structures/COVID19orf8_Q6UW63.pdb',
#  'oriented_structures/COVID19orf9c_O43292.pdb',
#  'oriented_structures/COVID19nsp1_P49642.clean.pdb',
#  'oriented_structures/COVID19orf8_Q8N766.pdb',
#  'oriented_structures/COVID19nsp13_Q9BV73.pdb',
#  'oriented_structures/COVID19nsp8_Q9H6F5.clean.pdb',
#  'oriented_structures/COVID19nsp8_O95260.pdb',
#  'oriented_structures/COVID19nsp7_O43169.pdb',
#  'oriented_structures/COVID19nsp8_Q92552.pdb',
#  'oriented_structures/COVID19Spike_Q9C0B5.pdb',
#  'oriented_structures/COVID19nsp8_Q9BSC4.pdb',
#  'oriented_structures/COVID19orf8_Q9BRN9.clean.pdb',
#  'oriented_structures/COVID19orf9c_Q86VR2.pdb',
#  'oriented_structures/COVID19orf8_P26358.pdb',
#  'oriented_structures/COVID19nsp13_P17612.pdb',
#  'oriented_structures/COVID19orf8_P0C7P0.pdb',
#  'oriented_structures/COVID19orf7a_Q9NU22.pdb',
#  'oriented_structures/COVID19orf8_P15151.pdb',
#  'oriented_structures/COVID19nsp2_Q5T1M5.pdb',
#  'oriented_structures/COVID19nsp13_Q66GS9.pdb',
#  'oriented_structures/COVID19nsp7_P51149.pdb',
#  'oriented_structures/COVID19orf9c_P55085.pdb',
#  'oriented_structures/COVID19Spike_Q7Z5G4.pdb',
#  'oriented_structures/COVID19nsp7_P61106.pdb',
#  'oriented_structures/COVID19nsp7_Q96DA6.pdb',
#  'oriented_structures/COVID19nsp12_Q6UUV7.pdb',
#  'oriented_structures/COVID19nsp7_Q7LGA3.clean.clean.pdb',
#  'oriented_structures/COVID19nsp13_Q9Y2I6.pdb',
#  'oriented_structures/COVID19nsp13_Q04726.pdb',
#  'oriented_structures/COVID19nsp13_Q5VU43.pdb',
#  'oriented_structures/COVID19nsp13_Q9BQQ3.pdb',
#  'oriented_structures/COVID19orf8_Q9H4F8.pdb',
#  'oriented_structures/COVID19nsp10_O94973.pdb',
#  'oriented_structures/COVID19nsp10_Q9HAV7.pdb',
#  'oriented_structures/COVID19orf8_Q9H8W4.pdb',
#  'oriented_structures/COVID19orf9c_Q9Y276.pdb',
#  'oriented_structures/COVID19nsp12_Q8IWR0.pdb',
#  'oriented_structures/COVID19nsp12_Q99081.pdb',
#  'oriented_structures/COVID19orf8_Q13443.pdb',
#  'oriented_structures/COVID19orf9c_Q6NXT6.pdb',
#  'oriented_structures/COVID19nsp9_P35555.pdb',
#  'oriented_structures/COVID19nsp10_O94973.clean.pdb',
#  'oriented_structures/COVID19nsp12_Q2T9J0.pdb',
#  'oriented_structures/COVID19orf9c_O00124.pdb',
#  'oriented_structures/COVID19orf9b_O94826.pdb',
#  'oriented_structures/COVID19nsp7_O00116.clean.pdb',
#  'oriented_structures/COVID19nsp7_P00387.pdb',
#  'oriented_structures/COVID19orf8_Q9NYU1.clean.pdb',
#  'oriented_structures/COVID19nsp2_O14975.pdb',
#  'oriented_structures/COVID19orf9b_O43633.pdb',
#  'oriented_structures/COVID19nsp7_Q8WTV0.pdb',
#  'oriented_structures/COVID19orf9c_Q9H3K2.clean.pdb',
#  'oriented_structures/COVID19nsp1_P49643.pdb',
#  'oriented_structures/COVID19nsp13_Q96SN8.pdb',
#  'oriented_structures/COVID19nsp8_O00566.pdb',
#  'oriented_structures/COVID19nsp5C145A_Q9NXH9.pdb',
#  'oriented_structures/COVID19orf8_P12109.clean.pdb',
#  'oriented_structures/COVID19orf8_Q08431.pdb',
#  'oriented_structures/COVID19nsp8_P61011.pdb',
#  'oriented_structures/COVID19orf8_Q92820.pdb',
#  'oriented_structures/COVID19nsp9_Q15056.pdb',
#  'oriented_structures/COVID19nsp7_Q8WVC6.clean.pdb',
#  'oriented_structures/COVID19nsp13_Q8N3C7.pdb',
#  'oriented_structures/COVID19nsp12_Q13546.pdb',
#  'oriented_structures/COVID19orf9c_Q9Y3A6.pdb',
#  'oriented_structures/COVID19orf8_P29122.pdb',
#  'oriented_structures/COVID19orf9b_Q9UKA9.clean.pdb',
#  'oriented_structures/COVID19orf9b_Q9H773.pdb',
#  'oriented_structures/COVID19nsp14_Q9NXA8.pdb',
#  'oriented_structures/COVID19nsp13_Q96N16.pdb',
#  'oriented_structures/COVID19nsp7_Q6ZRP7.pdb',
#  'oriented_structures/COVID19nsp8_Q9NY61.pdb',
#  'oriented_structures/COVID19orf9c_P33527.pdb',
#  'oriented_structures/COVID19orf8_Q99519.pdb',
#  'oriented_structures/COVID19nsp12_Q5JSZ5.pdb',
#  'oriented_structures/COVID19nsp7_Q9NP72.pdb',
#  'oriented_structures/COVID19nsp10_P55789.pdb',
#  'oriented_structures/COVID19nsp13_O75506.pdb',
#  'oriented_structures/COVID19orf8_Q9UHI8.pdb',
#  'oriented_structures/COVID19orf8_O00469.clean.pdb',
#  'oriented_structures/COVID19orf6_P52948.pdb',
#  'oriented_structures/COVID19orf9c_Q2PZI1.pdb',
#  'oriented_structures/COVID19nsp9_Q99567.pdb',
#  'oriented_structures/COVID19nsp12_Q5EBL8.pdb',
#  'oriented_structures/COVID19nsp12_O75592.pdb',
#  'oriented_structures/COVID19nsp8_Q13206.pdb',
#  'oriented_structures/COVID19nsp2_P52306.pdb',
#  'oriented_structures/COVID19nsp1_P09884.clean.clean.pdb',
#  'oriented_structures/COVID19nsp8_Q9HD40.pdb',
#  'oriented_structures/COVID19nsp13_Q8IUD2.pdb',
#  'oriented_structures/COVID19orf8_Q9BS26.pdb',
#  'oriented_structures/COVID19nsp12_Q9H2H8.pdb',
#  'oriented_structures/COVID19orf8_Q9P2E5.pdb',
#  'oriented_structures/COVID19orf8_Q7Z4H8.clean.pdb',
#  'oriented_structures/COVID19orf8_Q8N0Z8.pdb',
#  'oriented_structures/COVID19nsp13_O14578.pdb',
#  'oriented_structures/COVID19nsp12_Q5VUA4.pdb',
#  'oriented_structures/COVID19orf8_Q86YB8.pdb',
#  'oriented_structures/COVID19nsp7_P62820.pdb',
#  'oriented_structures/COVID19nsp9_P37198.pdb',
#  'oriented_structures/COVID19orf8_Q15818.clean.pdb',
#  'oriented_structures/COVID19orf9c_Q9Y375.pdb',
#  'oriented_structures/COVID19orf8_Q9H173.pdb',
#  'oriented_structures/COVID19nsp7_P61586.pdb',
#  'oriented_structures/COVID19nsp12_O95391.pdb',
#  'oriented_structures/COVID19nsp13_A7MCY6.pdb',
#  'oriented_structures/COVID19orf9b_P27448.pdb',
#  'oriented_structures/COVID19nsp9_Q96F45.clean.pdb',
#  'oriented_structures/COVID19nsp7_Q9H7Z7.pdb',
#  'oriented_structures/COVID19nsp4_Q9BSF4.pdb',
#  'oriented_structures/COVID19nsp7_Q5VT66.pdb',
#  'oriented_structures/COVID19orf6_P78406.pdb',
#  'oriented_structures/COVID19orf8_Q9NXK8.pdb',
#  'oriented_structures/COVID19orf7a_Q7Z4Q2.clean.pdb',
#  'oriented_structures/COVID19nsp4_Q2TAA5.pdb',
#  'oriented_structures/COVID19nsp2_Q2M389.pdb',
#  'oriented_structures/COVID19nsp8_Q7L2J0.pdb',
#  'oriented_structures/COVID19nsp13_Q9UJC3.pdb',
#  'oriented_structures/COVID19orf9c_Q86UT6.pdb',
#  'oriented_structures/COVID19nsp9_P13984.pdb',
#  'oriented_structures/COVID19orf9c_Q96K12.pdb',
#  'oriented_structures/COVID19orf9c_Q6NXT4.pdb',
#  'oriented_structures/COVID19nsp13_Q92995.pdb',
#  'oriented_structures/COVID19nsp9_Q8TD19.pdb',
#  'oriented_structures/COVID19orf9c_Q7Z2K6.pdb',
#  'oriented_structures/COVID19orf8_Q9BZQ6.pdb',
#  'oriented_structures/COVID19orf6_Q9NZJ7.pdb',
#  'oriented_structures/COVID19nsp2_P16435.pdb',
#  'oriented_structures/COVID19orf8_Q8IWF2.pdb',
#  'oriented_structures/COVID19orf8_Q99988.clean.pdb',
#  'oriented_structures/COVID19nsp13_Q4V328.clean.pdb',
#  'oriented_structures/COVID19nsp8_Q9ULT8.pdb',
#  'oriented_structures/COVID19nsp7_P61026.pdb',
#  'oriented_structures/COVID19orf9c_Q9Y6M9.pdb',
#  'oriented_structures/COVID19nsp12_Q14157.pdb',
#  'oriented_structures/COVID19nsp8_Q13868.pdb',
#  'oriented_structures/COVID19nsp12_O43823.pdb',
#  'oriented_structures/COVID19nsp7_Q13724.pdb',
#  'oriented_structures/COVID19orf9b_Q9UL15.pdb',
#  'oriented_structures/COVID19nsp8_P09132.pdb',
#  'oriented_structures/COVID19nsp7_Q8WUY8.pdb',
#  'oriented_structures/COVID19nsp8_Q96I59.clean.pdb',
#  'oriented_structures/COVID19orf8_Q8IV08.pdb',
#  'oriented_structures/COVID19nsp12_Q96IZ5.clean.pdb',
#  'oriented_structures/COVID19nsp13_O95684.pdb',
#  'oriented_structures/COVID19orf9c_Q96S52.pdb',
#  'oriented_structures/COVID19orf8_Q96DZ1.pdb',
#  'oriented_structures/COVID19orf8_O76061.pdb',
#  'oriented_structures/COVID19nsp8_Q4G0J3.clean.pdb',
#  'oriented_structures/COVID19nsp8_Q9Y399.pdb',
#  'oriented_structures/COVID19nsp4_P14735.clean.pdb',
#  'oriented_structures/COVID19orf9c_Q9BQ95.pdb',
#  'oriented_structures/COVID19nsp13_Q9UHD2.pdb',
#  'oriented_structures/COVID19nsp13_P31323.pdb',
#  'oriented_structures/COVID19nsp5C145A_P07203.pdb',
#  'oriented_structures/COVID19nsp7_Q9BQE4.pdb',
#  'oriented_structures/COVID19nsp13_Q76N32.pdb',
#  'oriented_structures/COVID19orf8_O14656.pdb',
#  'oriented_structures/COVID19orf8_Q8IZ52.clean.pdb',
#  'oriented_structures/COVID19nsp13_Q9BV19.pdb',
#  'oriented_structures/COVID19nsp9_P61962.pdb',
#  'oriented_structures/COVID19nsp7_O95573.pdb',
#  'oriented_structures/COVID19nsp13_Q7Z7A1.pdb',
#  'oriented_structures/COVID19nsp13_Q04724.pdb',
#  'oriented_structures/COVID19nsp13_Q8N8E3.pdb',
#  'oriented_structures/COVID19nsp7_P61019.pdb',
#  'oriented_structures/COVID19nsp7_P61006.clean.pdb',
#  'oriented_structures/COVID19nsp13_P13861.clean.pdb',
#  'oriented_structures/COVID19nsp4_Q9Y5J6.clean.clean.pdb',
#  'oriented_structures/COVID19nsp12_Q5T6F2.pdb',
#  'oriented_structures/COVID19nsp13_Q8TD10.pdb',
#  'oriented_structures/COVID19orf9c_Q9GZU3.pdb',
#  'oriented_structures/COVID19orf8_P05556.pdb',
#  'oriented_structures/COVID19nsp1_Q8NBJ5.pdb',
#  'oriented_structures/COVID19nsp13_Q9BQS8.pdb',
#  'oriented_structures/COVID19nsp7_P63218.pdb',
#  'oriented_structures/COVID19nsp13_O95613.pdb',
#  'oriented_structures/COVID19nsp7_Q5JTV8.pdb',
#  'oriented_structures/COVID19nsp1_Q99959.pdb',
#  'oriented_structures/COVID19orf8_P61916.pdb',
#  'oriented_structures/COVID19nsp9_Q86YT6.pdb',
#  'oriented_structures/COVID19nsp7_Q12907.pdb',
#  'oriented_structures/COVID19orf8_P00750.pdb',
#  'oriented_structures/COVID19orf9b_O75534.pdb',
#  'oriented_structures/COVID19nsp8_O96028.pdb',
#  'oriented_structures/COVID19orf9c_Q12770.pdb',
#  'oriented_structures/COVID19orf8_Q99470.pdb',
#  'oriented_structures/COVID19nsp12_Q92615.clean.pdb',
#  'oriented_structures/COVID19nsp13_Q14789.pdb',
#  'oriented_structures/COVID19nsp14_P12268.pdb',
#  'oriented_structures/COVID19orf8_P58166.pdb',
#  'oriented_structures/COVID19nsp13_Q08117.clean.pdb',
#  'oriented_structures/COVID19orf8_Q9Y4L1.pdb',
#  'oriented_structures/COVID19nsp8_O76094.pdb',
#  'oriented_structures/COVID19orf9c_Q8TEQ8.pdb',
#  'oriented_structures/COVID19nsp13_Q8IWJ2.pdb',
#  'oriented_structures/COVID19orf9b_Q7KZI7.pdb',
#  'oriented_structures/COVID19orf8_Q13438.clean.pdb',
#  'oriented_structures/COVID19nsp13_P35241.pdb',
#  'oriented_structures/COVID19nsp12_Q70EL1.clean.pdb',
#  'oriented_structures/COVID19orf8_P28300.pdb',
#  'oriented_structures/COVID19nsp14_P06280.pdb',
#  'oriented_structures/COVID19nsp15_P61970.pdb',
#  'oriented_structures/COVID19nsp8_P82663.pdb',
#  'oriented_structures/COVID19nsp13_Q08378.pdb',
#  'oriented_structures/COVID19nsp8_Q8NEJ9.pdb',
#  'oriented_structures/COVID19nsp2_Q6Y7W6.pdb',
#  'oriented_structures/COVID19orf8_Q96MM7.pdb',
#  'oriented_structures/COVID19orf8_Q96AY3.pdb',
#  'oriented_structures/COVID19nsp7_P11233.pdb',
#  'oriented_structures/COVID19nsp2_O60573.clean.pdb',
#  'oriented_structures/COVID19nsp7_Q96A26.clean.pdb',
#  'oriented_structures/COVID19orf9c_Q5BJF2.pdb',
#  'oriented_structures/COVID19nsp9_Q9BVL2.clean.pdb',
#  'oriented_structures/COVID19orf9c_Q9H845.pdb',
#  'oriented_structures/COVID19orf9c_O76024.clean.pdb',
#  'oriented_structures/COVID19nsp9_Q8N0X7.pdb',
#  'oriented_structures/COVID19orf8_Q96IV0.pdb',
#  'oriented_structures/COVID19nsp15_P62330.clean.pdb',
#  'oriented_structures/COVID19nsp1_Q14181.clean.pdb',
#  'oriented_structures/COVID19nsp15_Q9H4P4.clean.pdb',
#  'oriented_structures/COVID19nsp9_P35658.clean.clean.pdb',
#  'oriented_structures/COVID19nsp13_Q8N4C6.clean.pdb',
#  'oriented_structures/COVID19nsp12_Q9HAU0.pdb',
#  'oriented_structures/COVID19orf9c_Q9BVK2.pdb',
#  'oriented_structures/COVID19orf9b_Q9H2P9.pdb',
#  'oriented_structures/COVID19nsp10_Q969X5.pdb',
#  'oriented_structures/COVID19orf8_Q96F46.pdb',
#  'oriented_structures/COVID19nsp13_Q96CN9.clean.pdb',
#  'oriented_structures/COVID19nsp9_Q9UBX5.clean.pdb',
#  'oriented_structures/COVID19nsp7_P62873.pdb',
#  'oriented_structures/COVID19nsp4_Q8TEM1.clean.pdb',
#  'oriented_structures/COVID19nsp8_P82675.pdb',
#  'oriented_structures/COVID19nsp7_P21964.pdb',
#  'oriented_structures/COVID19orf8_Q9H488.clean.pdb',
#  'oriented_structures/COVID19nsp7_Q8N183.pdb',
#  'oriented_structures/COVID19orf9b_O14745.pdb',
#  'oriented_structures/COVID19orf9b_Q9P0L2.pdb',
#  'oriented_structures/COVID19nsp12_O14874.pdb',
#  'oriented_structures/COVID19nsp4_Q9NVH1.pdb',
#  'oriented_structures/COVID19nsp5_Q92769.pdb',
#  'oriented_structures/COVID19nsp7_Q8NBX0.pdb']

# %%
s = 
print s
print os.path.exists(s)
# Out:
# [REDACTED_PATH]/Collaborators/Resource_Maintenance/2020_04_27_Guided_Docking_Test/docking_outputs/COVID19nsp7_Q96A26_1_0.pdb
# True

# %%
# Out:
# '[REDACTED_PATH]/Collaborators/Resource_Maintenance/2020_04_27_Guided_Docking_Test/docking_outputs/COVID19nsp7_Q96A26_1.pdb'

# %%
input_pdbs[0]
# Out:
# 'oriented_structures/COVID19nsp7_Q96A26.pdb'

# %%
for p in processes:
    try:
        p["p"].kill()
    except:
        pass

# %%
0
# Out:
# 0

# %%
os.getcwd()
# Out:
# '[REDACTED_PATH]Collaborators/Resource_Maintenance/2020_04_27_Guided_Docking_Test'
