# %%
# Set the process name to be human readable in htop
import setproctitle
setproctitle.setproctitle("12_Run_SARS1_SARS2_ddG_Predictions")

from config import *
from helper_functions import pdb2df

import pandas as pd
pd.options.display.max_columns = 999

import numpy as np

import glob
import os

from tqdm import tqdm, tqdm_notebook
from tqdm._tqdm_notebook import tqdm_notebook

tqdm.pandas(tqdm_notebook)
tqdm_notebook.pandas()

from collections import defaultdict
import scipy

# %% [markdown]
# # Paramaters for file locations

# %%
# Base directory for whole project
base_dir = "/home/sdw95/3D_SARS2"

# Base output directory for mutated structures
# NOTE: Trailing "/" here is necessary based on how out_base
#       is used in Mutant_ddG_Calc.py
out_base = "{0}/Data/ddG_Mutated_Structures/".format(base_dir)

# %%
# Make necessary paths
if(not os.path.exists("{0}".format(out_base))):
    os.mkdir("{0}".format(out_base))
if(not os.path.exists("{0}Structures/".format(out_base))):
    os.mkdir("{0}Structures/".format(out_base))
if(not os.path.exists("{0}Summary_Logs/".format(out_base))):
    os.mkdir("{0}Summary_Logs/".format(out_base))

# %% [markdown]
# # Run ddG Calculations for all docked interactions

# %%
# Read in docking summary (we could theoretcally
# want to calculate this value on all docking attempts
# but for here we will just filter to the top-ranked)
ppi_docking = pd.read_csv("{0}/Data/Docking_Summary.txt".format(base_dir), sep="\t")

ppi_docking = ppi_docking[ppi_docking["Rank"] == 1]

# %%
# Read in Viral Muts
# For this ddG calculation we start with our docked SARS2-Human
# protein and want to introduce mutations to change the SARS2 protein
# into the SARS1 equivalent. We need to know which mutations to make.
viral2muts = defaultdict(set)

viral_muts = pd.read_csv("{0}/Data/Viral_Muts.txt".format(base_dir), sep="\t")
for prot, pos, aa_ref, aa_alt in viral_muts[["COVID_ID", "COVID_Pos", "COVID_AA", "SARS_AA"]].values:
    if(not (aa_alt == "" or pd.isnull(aa_alt))):
        viral2muts[prot].add((pos, aa_alt))

# %%
def run_ddg_calc(p1, p2, pdb, rank, muts, trials, interface_cutoff, out_base=out_base):
    cmd = "nice python Mutant_ddG_Calc.py {0} {1} {2} {3} {4} {5} {6} {7}".format(p1, p2, pdb, rank, muts, trials, interface_cutoff, out_base)
    print cmd
    p = sp.Popen(cmd, shell=True)
    return {"p":p, "cmd":cmd, "start_time":time.time(), "end_time":None, "in":(p1, p2, rank)}
# FUNCTION END

# %%
import subprocess as sp
import time
# Run Ligand Docking in Loop
i_num = 1
finished_processes = []
processes = []

max_processes = 25

trials = 50
interface_cutoff = 8.0
# Iterate over all Docking Inputs
for p1, p2, pdb, rank in tqdm_notebook(ppi_docking.sort_values(["Rank", "P1", "P2"])[["P1", "P2", "File", "Rank"]].values):
    if(os.path.exists("{0}/Data/ddG_Mutated_Structures/Summary_Logs/{1}_{2}_{3}".format(base_dir, p1, p2, rank))):
        continue
    
    # Obtain list of viral muts
    muts = viral2muts[p1]
    
    # Obtain coverage info for viral protein in docked structure
    # (Could theoretically be done ahead of time / all in one go
    #  particularly if running for all docked trials. This setup
    #  of reading in the pdb is slower than necessary. e.g. we
    #  have a table describing the coverage of all models used
    #  could read that in instead, and create a uni2coverage map)
    pdb_df = my.pdb2df(pdb)
    resis = set(pdb_df[pdb_df["Chain"] == "A"]["Residue ID"].unique())
    
    # Obtain list of all viral sequence deviations covered by the available structure
    muts = [x for x in muts if x[0] in resis]
    
    # If we don't have any deviations between SARS1 and SARS2, this calculation
    # is meaningless so we skip it
    if(len(muts) == 0):
        continue
    
    # Parse Muts as input for sub-process call to run the actual
    # ddG calculation
    muts = ",".join("_".join([str(y) for y in x]) for x in muts)
    
    # Block new jobs if too many running already
    while(True):
        # Only submit next ddG calculation job if we aren't
        # already at max allowed processes
        if(len(processes) <= max_processes):
            p = run_ddg_calc(p1, p2, pdb, rank, muts, trials, interface_cutoff)
            processes.append(p)
            break
        # Otherwise we wait for processes to finish
        else:
            # Give time for jobs to finish
            time.sleep(5)
            
            # Parse currently running jobs to remove any that
            # have finished
            new_processes = []
            for p in processes:
                # Process not finished, keep in list
                if(p["p"].poll() is None):
                    new_processes.append(p)
                # Process ended in error
                elif(p["p"].poll() != 0):
                    p["end_time"] = time.time()
                    print "Error", p["p"].poll()
                    print "cmd:", p["cmd"]
                    print "RunTime:", (p["end_time"] - p["start_time"])
                    print
                    finished_processes.append(p)
                # Process ended successfully
                else:
                    p["end_time"] = time.time()
                    print "Finished ddG", p["in"], "in", (p["end_time"] - p["start_time"])
                    finished_processes.append(p)
            processes = new_processes
            
# Wait to completion of all processes
while(True):
    if(len(processes) == 0):
        break
    else:
        new_processes = []
        for p in processes:
            if(p["p"].poll() is None):
                new_processes.append(p)
            elif(p["p"].poll() != 0):
                p["end_time"] = time.time()
                print "Error", p["p"].poll()
                print "cmd:", p["cmd"]
                print "RunTime:", (p["end_time"] - p["start_time"])
                print
                finished_processes.append(p)
            else:
                p["end_time"] = time.time()
                print "Finished ddG", p["in"], "in", (p["end_time"] - p["start_time"])
                finished_processes.append(p)
        processes = new_processes
        time.sleep(5)
# Out:
# ...
# /home/sdw95/bin/helper.py:3782: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.header = header
# /home/sdw95/bin/helper.py:3783: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.tailer = tailer
# C
# C
# C
# C
# C
# C
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B

# %%
# Process kill all block (just in case running need to be
# interrupted)
for p in processes:
    p["p"].kill()

# %% [markdown]
# # Parse whole interaction ddG values

# %%
# Read raw ddG summaries
ddGs = pd.concat([pd.read_csv(x, sep="\t") for x in tqdm_notebook(glob.glob("{0}/Data/ddG_Mutated_Structures/Summary_Logs/*".format(base_dir)))])
ddGs = ddGs.sort_values(["P1", "P2", "Docking_Rank", "ddG_Trial"])
ddGs.head()
# Out:
# ...
#          P1      P2  Docking_Rank  ddG_Trial    WT_Score      WT_dG  \
# 0  COVID19N  O43818             1          0  552.631306  19.985541
# 1  COVID19N  O43818             1          1  552.780047  20.408422
# 2  COVID19N  O43818             1          2  552.780047  20.134282
# 3  COVID19N  O43818             1          3  552.631306  19.658979
# 4  COVID19N  O43818             1          4  552.631306  19.985541
#
#     Mut_Score     Mut_dG        ddG  \
# 0  617.893956  83.268322  63.282781
# 1  618.649644  84.741863  64.333440
# 2  617.893956  83.659614  63.525332
# 3  618.249776  83.669369  64.010389
# 4  617.893956  83.472323  63.486783
#
#                                              pdbfile
# 0  Data/ddG_Mutated_Structures/Structures/COVID19...
# 1  Data/ddG_Mutated_Structures/Structures/COVID19...
# 2  Data/ddG_Mutated_Structures/Structures/COVID19...
# 3  Data/ddG_Mutated_Structures/Structures/COVID19...
# 4  Data/ddG_Mutated_Structures/Structures/COVID19...

# %%
# Save merged summary
ddGs.to_csv("{0}/Data/ddG_All.txt".format(base_dir), sep="\t", index=None)

# %%
# Combine individual ddG trials per interaction
# to obtain an average ddG / determine if the trials
# are significantly non-zero
summary = []
for g in tqdm_notebook(ddGs[ddGs["Docking_Rank"] <= 1].groupby(["P1", "P2"])):
    p1, p2 = g[0]
    if(p2 == "ACE2"):
        continue
    
    #tmp = g[1][g[1]["ddG"] != 0]
    #if(len(tmp) == 0):
    tmp = g[1]
    wt_score, wt_dg, mut_score, mut_dg, ddg = tmp[["WT_Score", "WT_dG", "Mut_Score", "Mut_dG", "ddG"]].mean(axis=0)
    ddg = -ddg
    wt_score_std, wt_dg_std, mut_score_std, mut_dg_std, ddg_std = tmp[["WT_Score", "WT_dG", "Mut_Score", "Mut_dG", "ddG"]].std(axis=0)
    best_file = g[1][(g[1]["ddG"] - ddg) == (g[1]["ddG"] - ddg).min()]["pdbfile"].values[0]
    try:
        p = scipy.stats.norm.sf(abs(ddg / ddg_std))
    except ZeroDivisionError:
        p = 1
    summary.append([p1.replace("COVID19", ""), p2, wt_score, wt_score_std, wt_dg, wt_dg_std, mut_score, mut_score_std, mut_dg, mut_dg_std, ddg, ddg_std, p, best_file])
summary = pd.DataFrame(summary, columns=["P1", "P2", "WT_Score", "WT_Score_Std", "WT_dG", "WT_dG_Std", "Mut_Score", "Mut_Score_Std", "Mut_dG", "Mut_dG_Std", "ddG", "ddG_Std", "p-value", "pdbfile"])

# %%
summary[(summary["p-value"] <= 0.05)&(summary["ddG"].abs() > 0.1)].sort_values("ddG")
# Out:
#            P1      P2     WT_Score  WT_Score_Std       WT_dG     WT_dG_Std  \
# 71      orf3a  Q9UH99   427.770883  1.043926e+00   43.577139  1.746761e+00
# 0           N  O43818   552.746875  1.045613e-01   20.049941  2.411265e-01
# 75      orf9b  O94826   251.136299  4.308319e-01    6.556030  5.100149e-01
# 12       nsp1  P49643   586.782342  4.362033e-01   87.814239  6.089795e-01
# 78      orf9b  Q9H2P9   415.792501  4.616254e-01   22.329729  6.047249e-01
# 79      orf9b  Q9H773   222.971023  7.690263e-01   16.690820  9.178322e-01
# 5           N  Q8TAD8   513.819496  3.036914e-02   12.351617  4.269204e-02
# 52      nsp15  Q9H4P4   564.077950  8.207407e-01   41.801234  9.436817e-01
# 76      orf9b  P27448   778.777511  6.247959e-01   38.360610  7.515693e-01
# 13       nsp1  Q99959   462.985648  7.282888e-01   31.324904  8.778689e-01
# 54  nsp5C145A  P07203   603.211789  8.327448e-01   34.680584  1.087454e+00
# ...

# %%
# Calculate Z-score (comparing accross all interactions)
# Correct normalization by removing two extreme outliers
print summary["ddG"].mean(), summary["ddG"].std()
summary["z-score"] = (summary["ddG"] - summary["ddG"].mean()) / summary["ddG"].std()
tmp = summary[summary["z-score"].abs() <= 3]
print len(tmp)
print tmp["ddG"].mean(), tmp["ddG"].std()
summary["z-score"] = (summary["ddG"] - tmp["ddG"].mean()) / tmp["ddG"].std()
# Out:
# -3.26610427993 19.6971436652
# 81
# -0.569796413542 5.77534826881

# %%
# Check most significant hits
summary[((summary["z-score"].abs() >= 1)&(summary["p-value"] <= 0.05))].sort_values("ddG")
# Out:
#        P1      P2    WT_Score  WT_Score_Std      WT_dG  WT_dG_Std   Mut_Score  \
# 71  orf3a  Q9UH99  427.770883      1.043926  43.577139   1.746761  594.850134
# 0       N  O43818  552.746875      0.104561  20.049941   0.241127  618.342035
# 75  orf9b  O94826  251.136299      0.430832   6.556030   0.510015  268.863304
# 12   nsp1  P49643  586.782342      0.436203  87.814239   0.608980  547.477216
# 78  orf9b  Q9H2P9  415.792501      0.461625  22.329729   0.604725  430.080093
# 79  orf9b  Q9H773  222.971023      0.769026  16.690820   0.917832  236.584027
# 5       N  Q8TAD8  513.819496      0.030369  12.351617   0.042692  526.708907
# 52  nsp15  Q9H4P4  564.077950      0.820741  41.801234   0.943682  587.120037
# 11   nsp1  P49642  667.513332      0.341270  37.869137   0.473285  666.706056
# 77  orf9b  Q7KZI7  492.829806      0.667336  51.802642   0.718247  487.815656
# 50  nsp15  P61970  591.871840      1.402638  47.441761   1.605618  582.534657
# ...

# %%
# Obtain gene name mapping
proteins = pd.read_csv("{0}/Data/Proteins.txt".format(base_dir), sep="\t")
uni2gene = proteins.set_index("ID")["Gene_Name"].to_dict()

# %%
# Plot
plt.figure(figsize=(20, 5))
plot_df = summary[summary["p-value"] <= 10.05].sort_values("ddG")[["P1", "P2", "ddG", "ddG_Std", "p-value"]].set_index(["P1", "P2"])[["ddG"]].T
#labels = summary[summary["p-value"] <= 10.05].sort_values("ddG")[["P1", "P2", "ddG", "ddG_Std", "p-value"]][["P1", "P2"]].apply(lambda x: " ".join([x[0].replace("COVID19", ""), uni2gene[x[1]]]), axis=1)
#labels = [x[0] if x[1] else "" for x in zip(labels, list((summary[summary["p-value"] <= 10.05].sort_values("ddG")["p-value"] <= 0.05)&(summary[summary["p-value"] <= 10.05].sort_values("ddG")["ddG"].abs() >= 0.1)))]
labels = summary.sort_values("ddG")[["P1", "P2"]].apply(lambda x: " ".join([x[0].replace("COVID19", ""), uni2gene[x[1]]]), axis=1)
labels = [x[0] if x[1] else "" for x in zip(labels, ((summary.sort_values("ddG")["z-score"].abs() >= 1)&(summary.sort_values("ddG")["p-value"] <= 0.05)).values)]

sns.heatmap(plot_df, annot=False, cmap="seismic", center=0, vmin=-30, vmax=30, xticklabels=labels)
plt.savefig("../Figures/Figure_4_b.svg")

# %%
print summary["ddG"].mean()
print summary["ddG"].std()
# Out:
# -3.26610427993
# 19.6971436652

# %%
print sum(summary["ddG"] < 0)
print sum(summary["ddG"] > 0)
# Out:
# 51
# 32

# %%
plot_df
# Out:
# P1        orf3a          N      orf9b       nsp1      orf9b             \
# P2       Q9UH99     O43818     O94826     P49643     Q9H2P9     Q9H773
# ddG -160.981621 -63.951525 -18.053224 -17.288684 -17.152873 -14.703822
#
# P1           N     Spike     nsp15     orf9b      nsp1 nsp5C145A      nsp5  \
# P2      Q8TAD8    Q7Z5G4    Q9H4P4    P27448    Q99959    P07203    Q92769
# ddG -10.718892 -8.337198 -7.720902 -5.752968 -5.746741 -3.069503 -3.039905
#
# P1      orf9b         N     orf9b         N                         orf9b  \
# P2     Q9P0L2    Q13283    O43633    Q6PKG0    Q9Y3U8    P19784    Q9UKA9
# ddG -2.636089 -1.992145 -1.391328 -1.376032 -1.064636 -1.037809 -0.974554
#
# P1      nsp12     orf3a     nsp12         N     nsp15     nsp10     nsp12  \
# P2     Q70EL1    Q8N6S5    O95391    P11940    P62330    Q96CW1    Q6UUV7
# ddG -0.862577 -0.817757 -0.723701 -0.655072 -0.648778 -0.616212 -0.599369
#
# ...

# %%
# Save Summary
summary.to_csv("{0}/Data/ddG_Summary.txt".format(base_dir), sep="\t", index=None)

# %% [markdown]
# # Explore Krogan differential binding data (Move elsewhere)

# %%
# Read in Krogan Dataset
data = pd.read_csv("/home/sdw95/3D_SARS2/Misc_Notebooks/2020_12_21_HY_Meeting/Krogan_Comparative_Interaction_Scores.txt", sep="\t")

# %%
# Rename / Select Columns of Interest
data["P1"] = data["Bait"]
data["P2"] = data["Bait_Prey"].map(lambda x: x.split("-")[1])
data = data[["P1", "P2", "DIS_SARS1_MERS", "DIS_SARS2_MERS", "DIS_SARS2_SARS1", "DIS_SARS_MERS"]]

# %%
# Read in predicted ddG Summary
pred_ddgs = pd.read_csv("../Data/ddG_Summary.txt", sep="\t")

# %%
# Join data by identical interactions
merged = pred_ddgs[["P1", "P2", "ddG", "ddG_Std", "p-value", "z-score"]].join(data.set_index(["P1", "P2"]), on=["P1", "P2"], how="inner")
print len(data)
print len(pred_ddgs)
print len(merged)
# Out:
# 537
# 83
# 50

# %%
x = merged["ddG"]
y = merged["DIS_SARS2_SARS1"]

m1 = (merged["z-score"] <= -1)&(merged["p-value"] <= 0.05)
m2 = y >= 0
plt.scatter(x[m1&m2], y[m1&m2], color="b")
plt.text(-60, 0.75, np.round(sum(m1&m2) / float(len(x)), 2))

m1 = (merged["z-score"] >= 1)&(merged["p-value"] <= 0.05)
m2 = y >= 0
plt.scatter(x[m1&m2], y[m1&m2], color="orange")
plt.text(40, 0.75, np.round(sum(m1&m2) / float(len(x)), 2))


m1 = (merged["z-score"] <= -1)&(merged["p-value"] <= 0.05)
m2 = y < 0
plt.scatter(x[m1&m2], y[m1&m2], color="orange")
plt.text(-60, -0.75, np.round(sum(m1&m2) / float(len(x)), 2))

m1 = (merged["z-score"] >= 1)&(merged["p-value"] <= 0.05)
m2 = y < 0
plt.scatter(x[m1&m2], y[m1&m2], color="red")
plt.text(40, -0.75, np.round(sum(m1&m2) / float(len(x)), 2))

m1 = (merged["z-score"].abs() < 1)|(merged["p-value"] >= 0.05)
plt.scatter(x[m1], y[m1], color="gray")

plt.ylim(-1, 1)
plt.xlim(-70, 70)
plt.axvline(0, linestyle="--", color="k")
plt.axhline(0, linestyle="--", color="k")

plt.xlabel("Rosetta ddG Prediction\n(Stronger SARS2 --> Weaker SARS2)")
plt.ylabel("Krogan Differential Interaction Score\n(SARS1 Specific --> SARS2 Specific)")
# Out:
# Text(0,0.5,'Krogan Differential Interaction Score\n(SARS1 Specific --> SARS2 Specific)')

# %%
# Interactions we predict to be stronger in SARS2 than SARS 1
merged[merged["z-score"] <= -1].sort_values("z-score")[["ddG", "DIS_SARS2_SARS1"]]
# Out:
#           ddG  DIS_SARS2_SARS1
# 0  -63.951525        -0.019521
# 12 -17.288684         0.172488
# 5  -10.718892         0.050895
# 52  -7.720902         0.996780

# %%
# We can plot the fraction of our predictions that are experimentally
# determined to be stronger SARS2 interactors
sub = merged[merged["z-score"] <= -1].sort_values("z-score")[["ddG", "DIS_SARS2_SARS1"]]
p = sum(sub["DIS_SARS2_SARS1"] >= 0) / float(len(sub))
sem = np.sqrt(p*(1-p) / float(len(sub)))
plt.bar(x=0, height=p, yerr=sem)
plt.text(-0.1, 0.9, "{0} / {1}".format(sum(sub["DIS_SARS2_SARS1"] >= 0), len(sub)))

sub = merged[merged["z-score"] >= 1].sort_values("z-score")[["ddG", "DIS_SARS2_SARS1"]]
p = sum(sub["DIS_SARS2_SARS1"] <= 0) / float(len(sub))
sem = np.sqrt(p*(1-p) / float(len(sub)))
plt.bar(x=1, height=p, yerr=sem)

plt.ylim(0, 1)
plt.xlim(-1, 2)
plt.xticks([0, 1], ["Predicted Strengthened", "Predicted Weakened"], rotation=30)
plt.ylabel("Fraction Supported by Experiments")
# Out:
# Text(0,0.5,'Fraction Supported by Experiments')

# %%
enrichments = pd.read_csv("../Data/Viral_Mut_Enrichment.txt", sep="\t")
inter2enrichment = enrichments[~pd.isnull(enrichments["LogOdds"])].set_index(["P1", "P2"])[["LogOdds", "P-value"]].to_dict()

# %%
y = []
x = []
colors = []
for p1, p2, score in data[~pd.isnull(data["DIS_SARS2_SARS1"])][["P1", "P2", "DIS_SARS2_SARS1"]].values:
    if(not ("COVID19" + p1, p2) in inter2enrichment["LogOdds"]):
        continue
    
    y.append(score)
    x.append(inter2enrichment["LogOdds"][("COVID19" + p1, p2)])
    p = inter2enrichment["P-value"][("COVID19" + p1, p2)]
    
    colors.append(((0.5 - 0.5*(min(3, np.log2(p) - np.log2(0.05), key=abs) / 3)), 0, 0.5 + 0.5*(min(3, np.log2(p) - np.log2(0.05), key=abs) / 3)))

plt.scatter(x, y, alpha=0.5, c=colors)
plt.ylim(-1.1, 1.1)
plt.xlim(-3, 3)
plt.axhline(0, linestyle="--", color="k")
plt.axvline(0, linestyle="--", color="k")
plt.xlabel("SARS1-SARS2 Interface Mutation Enrichment")
plt.ylabel("Krogan Differential Interaction Score\n(SARS1 Specific --> SARS2 Specific)")
# Out:
# Text(0,0.5,'Krogan Differential Interaction Score\n(SARS1 Specific --> SARS2 Specific)')

# %%
enrichments = pd.read_csv("../Data/Viral_Mut_Enrichment.txt", sep="\t")
inter2enrichment = enrichments[(~pd.isnull(enrichments["LogOdds"]))&(enrichments["P-value"] <= 0.05)].set_index(["P1", "P2"])["LogOdds"].to_dict()

# %%
y = []
x = []
for p1, p2, score in data[~pd.isnull(data["DIS_SARS2_SARS1"])][["P1", "P2", "DIS_SARS2_SARS1"]].values:
    if(not ("COVID19" + p1, p2) in inter2enrichment):
        continue
    
    y.append(score)
    x.append(inter2enrichment[("COVID19" + p1, p2)])
    print p1, p2


plt.scatter(x, y, alpha=0.5)
plt.ylim(-1.1, 1.1)
plt.xlim(-3, 3)
plt.axhline(0, linestyle="--", color="k")
plt.axvline(0, linestyle="--", color="k")
plt.xlabel("SARS1-SARS2 Interface Mutation Enrichment")
plt.ylabel("Krogan Differential Interaction Score\n(SARS1 Specific --> SARS2 Specific)")
# Out:
# nsp1 Q99959
# nsp15 P62330
# nsp15 Q9H4P4
# nsp2 O14975
# nsp2 O60573
# nsp2 P16435
# nsp2 P52306
# nsp2 Q2M389
# nsp2 Q5T1M5
# nsp2 Q6Y7W6
# nsp4 P14735
# nsp4 P62072
# nsp4 Q2TAA5
# nsp4 Q8TEM1
# nsp4 Q9BSF4
# nsp4 Q9NVH1
# nsp4 Q9Y5J6
# nsp4 Q9Y5J7
# Text(0,0.5,'Krogan Differential Interaction Score\n(SARS1 Specific --> SARS2 Specific)')

# %%
inter2enrichment
# Out:
# {('COVID19Spike', 'Q7Z5G4'): -1.80460431104,
#  ('COVID19Spike', 'Q9C0B5'): -2.6888713059700002,
#  ('COVID19nsp1', 'Q99959'): 2.078002512,
#  ('COVID19nsp15', 'P62330'): 1.67198885306,
#  ('COVID19nsp15', 'Q9H4P4'): 1.30305008468,
#  ('COVID19nsp2', 'O14975'): -0.834897382015,
#  ('COVID19nsp2', 'O60573'): -0.935742435186,
#  ('COVID19nsp2', 'P16435'): -0.906839840273,
#  ('COVID19nsp2', 'P52306'): -0.768140955359,
#  ('COVID19nsp2', 'Q2M389'): -1.31443355834,
#  ('COVID19nsp2', 'Q5T1M5'): -1.31443355834,
#  ('COVID19nsp2', 'Q6Y7W6'): -1.31443355834,
#  ('COVID19nsp4', 'P14735'): -2.5042672667,
#  ('COVID19nsp4', 'P62072'): -2.23275637867,
#  ('COVID19nsp4', 'Q2TAA5'): -2.16556460646,
#  ('COVID19nsp4', 'Q8TEM1'): -2.2639789754099997,
#  ('COVID19nsp4', 'Q9BSF4'): -2.2639789754099997,
#  ('COVID19nsp4', 'Q9NVH1'): -2.2639789754099997,
#  ('COVID19nsp4', 'Q9Y5J6'): -2.8171359428500002,
#  ('COVID19nsp4', 'Q9Y5J7'): -2.2386043670099998,
#  ('COVID19orf9b', 'Q9UL15'): 2.70043971814}

# %%
summary[summary["P2"].isin(["Q99959", "P62330", "Q9H4P4"])]
# Out:
#        P1      P2    WT_Score  WT_Score_Std      WT_dG  WT_dG_Std   Mut_Score  \
# 13   nsp1  Q99959  462.985648      0.728289  31.324904   0.877869  470.770493
# 51  nsp15  P62330  622.970569      0.585508  40.479977   1.078222  631.430250
# 52  nsp15  Q9H4P4  564.077950      0.820741  41.801234   0.943682  587.120037
#
#     Mut_Score_Std     Mut_dG  Mut_dG_Std       ddG   ddG_Std       p-value  \
# 13       1.076230  37.071644    1.370823 -5.746741  1.608354  1.764190e-04
# 51       1.082787  41.128756    1.534482 -0.648778  1.814154  3.603137e-01
# 52       0.591499  49.522136    0.777763 -7.720902  1.305167  1.652913e-09
#
#                                               pdbfile   z-score
# 13  Data/ddG_Mutated_Structures/Structures/COVID19... -0.896386
# 51  Data/ddG_Mutated_Structures/Structures/COVID19... -0.013676
# 52  Data/ddG_Mutated_Structures/Structures/COVID19... -1.238212
